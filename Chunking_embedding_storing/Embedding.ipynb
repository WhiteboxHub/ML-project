# %%
from Chunk_text_filess import sementic_chunking,ovelap_chunking,sentence_based_chunking,fixed_length_chunking
# Out:
# [nltk_data] Error loading punket-tab: Package 'punket-tab' not found
# [nltk_data]     in index
# [nltk_data] Error loading punket: Package 'punket' not found in index

# %%
import os
def get_file_paths(folder_path):
    text_file_paths = []
    for root,dirs,files in os.walk(folder_path):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                # Ensure double backslashes in paths for Windows
                text_file_paths.append(file_path.replace('\\', '/'))
    return text_file_paths

folder_path = '../Knowledgebase'
text_files = get_file_paths(folder_path)

# %%
text_files
# Out:
# ['../Knowledgebase/Intelligent_agent.txt',
#  '../Knowledgebase/Large_language_model.txt']

# %%
# %pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (0.3.14)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (0.3.30)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (0.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (4.12.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.14)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: httpcore==1.* in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: anyio in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ajukh\onedrive\desktop\ml-project\myenv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.2.2)
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\ajukh\OneDrive\Desktop\ML-project\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from langchain.embeddings.base import Embeddings
from sentence_transformers import SentenceTransformer

class SentenceTransformerEmbeddingModel(Embeddings):
    def __init__(self,modelname : str):
        self.model = SentenceTransformer(modelname)
    
    def embed_documents(self, texts):
        return [self.model.encode(d).tolist() for d in texts]

    def embed_query(self, query):
        return self.model.encode([query])[0].tolist()

# %%
model = 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'

myembedingmodel = SentenceTransformerEmbeddingModel(model)

# %%
# %pip install -qU faiss-cpu langchain_community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\ajukh\OneDrive\Desktop\ML-project\myenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

# %%
index = faiss.IndexFlatL2(len(myembedingmodel.embed_query("hello world")))

vector_store = FAISS(
    embedding_function=myembedingmodel,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
from langchain_core.documents import Document
from uuid import uuid4

docs = []
for file in text_files:
    text_chunks = ovelap_chunking(file,200)
    for chunk in text_chunks:
        print(chunk)
        doc = Document(page_content=chunk.page_content,metadata={"source":f"{file}"})
        docs.append(doc)
# Out:
# page_content='In intelligence and artificial intelligence, an intelligent agent (IA) is an agent that perceives its environment, takes actions autonomously in order to achieve goals, and may improve its performance'
# page_content='goals, and may improve its performance with learning or acquiring knowledge.'
# page_content='An intelligent agent may be simple or complex: A thermostat or other control system is considered an example of an intelligent agent, as is a human being, as is any system that meets the definition,'
# page_content='any system that meets the definition, such as a firm, a state, or a biome.[1]'
# page_content='Leading AI textbooks define "artificial intelligence" as the "study and design of intelligent agents", a definition that considers goal-directed behavior to be the essence of intelligence.'
# page_content='to be the essence of intelligence. Goal-directed agents are also described using a term borrowed from economics, "rational agent".[1]'
# page_content='An agent has an "objective function" that encapsulates all the IA's goals. Such an agent is designed to create and execute whatever plan will, upon completion, maximize the expected value of the'
# page_content='maximize the expected value of the objective function.[2]'
# page_content='For example, a reinforcement learning agent has a "reward function" that allows the programmers to shape the IA's desired behavior,[3] and an evolutionary algorithm's behavior is shaped by a "fitness'
# page_content='behavior is shaped by a "fitness function".[4]'
# page_content='Intelligent agents in artificial intelligence are closely related to agents in economics, and versions of the intelligent agent paradigm are studied in cognitive science, ethics, and the philosophy'
# page_content='science, ethics, and the philosophy of practical reason, as well as in many interdisciplinary socio-cognitive modeling and computer social simulations.'
# page_content='Intelligent agents are often described schematically as an abstract functional system similar to a computer program.'
# page_content='Abstract descriptions of intelligent agents are called abstract intelligent agents (AIA) to distinguish them from their real-world implementations.'
# page_content='An autonomous intelligent agent is designed to function in the absence of human intervention. Intelligent agents are also closely related to software agents. An autonomous computer program that'
# page_content='An autonomous computer program that carries out tasks on behalf of users.'
# page_content='Artificial Intelligence: A Modern Approach[5][6][2] defines an "agent" as'
# page_content='"Anything that can be viewed as perceiving its environment through sensors and acting upon that environment through actuators"
# It defines a "rational agent" as:'
# page_content='"An agent that acts so as to maximize the expected value of a performance measure based on past experience and knowledge."
# It also defines the field of "artificial intelligence research" as:'
# page_content='"The study and design of rational agents"'
# page_content='Padgham & Winikoff (2005) agree that an intelligent agent is situated in an environment and responds in a timely (though not necessarily real-time) manner to changes in the environment. However,'
# page_content='to changes in the environment. However, intelligent agents must also proactively pursue goals in a flexible and robust way.[a] Optional desiderata include that the agent be rational, and that the'
# page_content='the agent be rational, and that the agent be capable of belief-desire-intention analysis.[7]'
# page_content='Kaplan and Haenlein define artificial intelligence as "a system's ability to correctly interpret external data, to learn from such data, and to use those learnings to achieve specific goals and tasks'
# page_content='to achieve specific goals and tasks through flexible adaptation".[8] This definition is closely related to that of an intelligent agent.'
# page_content='Philosophically, this definition of artificial intelligence avoids several lines of criticism. Unlike the Turing test, it does not refer to human intelligence in any way. Thus, there is no need to'
# page_content='in any way. Thus, there is no need to discuss if it is "real" vs "simulated" intelligence (i.e., "synthetic" vs "artificial" intelligence) and does not indicate that such a machine has a mind,'
# page_content='that such a machine has a mind, consciousness or true understanding. It seems not to imply John Searle's "strong AI hypothesis". It also doesn't attempt to draw a sharp dividing line between'
# page_content='to draw a sharp dividing line between behaviors that are "intelligent" and behaviors that are "unintelligent"—programs need only be measured in terms of their objective function.'
# page_content='More importantly, it has a number of practical advantages that have helped move AI research forward. It provides a reliable and scientific way to test programs; researchers can directly compare or'
# page_content='researchers can directly compare or even combine different approaches to isolated problems, by asking which agent is best at maximizing a given "goal function".'
# page_content='It also gives them a common language to communicate with other fields—such as mathematical optimization (which is defined in terms of "goals") or economics (which uses the same definition of a'
# page_content='(which uses the same definition of a "rational agent").[9]'
# page_content='An agent that is assigned an explicit "goal function" is considered more intelligent if it consistently takes actions that successfully maximize its programmed goal function.'
# page_content='The goal can be simple: 1 if the IA wins a game of Go, 0 otherwise.
#
# Or the goal can be complex: Perform actions mathematically similar to ones that succeeded in the past.'
# page_content='The "goal function" encapsulates all of the goals the agent is driven to act on; in the case of rational agents, the function also encapsulates the acceptable trade-offs between accomplishing'
# page_content='trade-offs between accomplishing conflicting goals.'
# page_content='Terminology varies. For example, some agents seek to maximize or minimize an "utility function", "objective function" or "loss function".[6][2]'
# page_content='Goals can be explicitly defined or induced. If the AI is programmed for "reinforcement learning", it has a "reward function" that encourages some types of behavior and punishes others.'
# page_content='Alternatively, an evolutionary system can induce goals by using a "fitness function" to mutate and preferentially replicate high-scoring AI systems, similar to how animals evolved to innately desire'
# page_content='how animals evolved to innately desire certain goals such as finding food.[10]'
# page_content='Some AI systems, such as nearest-neighbor, instead of reason by analogy, these systems are not generally given goals, except to the degree that goals are implicit in their training data.[11] Such'
# page_content='in their training data.[11] Such systems can still be benchmarked if the non-goal system is framed as a system whose "goal" is to accomplish its narrow classification task.[12]'
# page_content='Systems that are not traditionally considered agents, such as knowledge-representation systems, are sometimes subsumed into the paradigm by framing them as agents that have a goal of (for example)'
# page_content='that have a goal of (for example) answering questions as accurately as possible; the concept of an "action" is here extended to encompass the "act" of giving an answer to a question. As an additional'
# page_content='answer to a question. As an additional extension, mimicry-driven systems can be framed as agents who are optimizing a "goal function" based on how closely the IA succeeds in mimicking the desired'
# page_content='IA succeeds in mimicking the desired behavior.[6][2] In the generative adversarial networks of the 2010s, an "encoder"/"generator" component attempts to mimic and improvise human text composition.'
# page_content='and improvise human text composition. The generator is attempting to maximize a function encapsulating how well it can fool an antagonistic "predictor"/"discriminator" component.[13]'
# page_content='While symbolic AI systems often accept an explicit goal function, the paradigm can also be applied to neural networks and to evolutionary computing. Reinforcement learning can generate intelligent'
# page_content='learning can generate intelligent agents that appear to act in ways intended to maximize a "reward function".[14] Sometimes, rather than setting the reward function to be directly equal to the'
# page_content='function to be directly equal to the desired benchmark evaluation function, machine learning programmers will use reward shaping to initially give the machine rewards for incremental progress in'
# page_content='rewards for incremental progress in learning.[15] Yann LeCun stated in 2018, "Most of the learning algorithms that people have come up with essentially consist of minimizing some objective'
# page_content='consist of minimizing some objective function."[16] AlphaZero chess had a simple objective function; each win counted as +1 point, and each loss counted as -1 point. An objective function for a'
# page_content='-1 point. An objective function for a self-driving car would have to be more complicated.[17] Evolutionary computing can evolve intelligent agents that appear to act in ways intended to maximize a'
# page_content='to act in ways intended to maximize a "fitness function" that influences how many descendants each agent is allowed to leave.[4]'
# page_content='The mathematical formalism of AIXI was proposed as a maximally intelligent agent in this paradigm.[18] However, AIXI is uncomputable. In the real world, an IA is constrained by finite time and'
# page_content='an IA is constrained by finite time and hardware resources, and scientists compete to produce algorithms that can achieve progressively higher scores on benchmark tests with existing hardware.[19]'
# page_content='A simple agent program can be defined mathematically as a function f (called the "agent function")[20] which maps every possible percepts sequence to a possible action the agent can perform or to a'
# page_content='action the agent can perform or to a coefficient, feedback element, function or constant that affects eventual actions:'
# page_content='Agent function is an abstract concept as it could incorporate various principles of decision making like calculation of utility of individual options, deduction over logic rules, fuzzy logic,'
# page_content='over logic rules, fuzzy logic, etc.[21]'
# page_content='The program agent, instead, maps every possible percept to an action.[22]'
# page_content='We use the term percept to refer to the agent's perceptional inputs at any given instant. In the following figures, an agent is anything that can be viewed as perceiving its environment through'
# page_content='as perceiving its environment through sensors and acting upon that environment through actuators.'
# page_content='Russell & Norvig (2003) group agents into five classes based on their degree of perceived intelligence and capability:[23]'
# page_content='Simple reflex agents act only on the basis of the current percept, ignoring the rest of the percept history. The agent function is based on the condition-action rule: "if condition, then action".'
# page_content='This agent function only succeeds when the environment is fully observable. Some reflex agents can also contain information on their current state which allows them to disregard conditions whose'
# page_content='them to disregard conditions whose actuators are already triggered.'
# page_content='Infinite loops are often unavoidable for simple reflex agents operating in partially observable environments. If the agent can randomize its actions, it may be possible to escape from infinite loops.'
# page_content='A model-based agent can handle partially observable environments. Its current state is stored inside the agent maintaining some kind of structure that describes the part of the world which cannot be'
# page_content='the part of the world which cannot be seen. This knowledge about "how the world works" is called a model of the world, hence the name "model-based agent".'
# page_content='A model-based reflex agent should maintain some sort of internal model that depends on the percept history and thereby reflects at least some of the unobserved aspects of the current state. Percept'
# page_content='aspects of the current state. Percept history and impact of action on the environment can be determined by using the internal model. It then chooses an action in the same way as reflex agent.'
# page_content='An agent may also use models to describe and predict the behaviors of other agents in the environment.[24]'
# page_content='Goal-based agents further expand on the capabilities of the model-based agents, by using "goal" information. Goal information describes situations that are desirable. This provides the agent a way to'
# page_content='This provides the agent a way to choose among multiple possibilities, selecting the one which reaches a goal state. Search and planning are the subfields of artificial intelligence devoted to finding'
# page_content='intelligence devoted to finding action sequences that achieve the agent's goals.'
# page_content='Goal-based agents only distinguish between goal states and non-goal states. It is also possible to define a measure of how desirable a particular state is. This measure can be obtained through the'
# page_content='measure can be obtained through the use of a utility function which maps a state to a measure of the utility of the state. A more general performance measure should allow a comparison of different'
# page_content='should allow a comparison of different world states according to how well they satisfied the agent's goals. The term utility can be used to describe how "happy" the agent is.'
# page_content='A rational utility-based agent chooses the action that maximizes the expected utility of the action outcomes - that is, what the agent expects to derive, on average, given the probabilities and'
# page_content='on average, given the probabilities and utilities of each outcome. A utility-based agent has to model and keep track of its environment, tasks that have involved a great deal of research on'
# page_content='involved a great deal of research on perception, representation, reasoning, and learning.'
# page_content='Learning has the advantage of allowing agents to initially operate in unknown environments and become more competent than their initial knowledge alone might allow. The most important distinction is'
# page_content='The most important distinction is between the "learning element", responsible for making improvements, and the "performance element", responsible for selecting external actions.'
# page_content='The learning element uses feedback from the "critic" on how the agent is doing and determines how the performance element, or "actor", should be modified to do better in the future. The performance'
# page_content='better in the future. The performance element, previously considered the entire agent, takes in percepts and decides on actions.'
# page_content='The last component of the learning agent is the "problem generator". It is responsible for suggesting actions that will lead to new and informative experiences.'
# page_content='Weiss (2013) defines four classes of agents:
#
# In 2013, Alexander Wissner-Gross published a theory pertaining to Freedom and Intelligence for intelligent agents.[25][26]'
# page_content='Intelligent agents can be organized hierarchically into multiple "sub-agents". Intelligent sub-agents process and perform lower-level functions. Taken together, the intelligent agent and sub-agents'
# page_content='the intelligent agent and sub-agents create a complete system that can accomplish difficult tasks or goals with behaviors and responses that display a form of intelligence.'
# page_content='Generally, an agent can be constructed by separating the body into the sensors and actuators, and so that it operates with a complex perception system that takes the description of the world as input'
# page_content='the description of the world as input for a controller and outputs commands to the actuator. However, a hierarchy of controller layers is often necessary to balance the immediate reaction desired for'
# page_content='the immediate reaction desired for low-level tasks and the slow reasoning about complex, high-level goals.[27]'
# page_content='"Intelligent agent" is also often used as a vague term, sometimes synonymous with "virtual personal assistant".[28] Some 20th-century definitions characterize an agent as a program that aids a user'
# page_content='an agent as a program that aids a user or that acts on behalf of a user.[29] These examples are known as software agents, and sometimes an "intelligent software agent" (that is, a software agent with'
# page_content='agent" (that is, a software agent with intelligence) is referred to as an "intelligent agent".'
# page_content='According to Nikola Kasabov, IA systems should exhibit the following characteristics:[30]'
# page_content='In the context of generative artificial intelligence, AI agents[31] (also known as compound AI systems,[31] agentic AI,[32][33][34] large action models,[32] or large agent models[32]) are agents'
# page_content='or large agent models[32]) are agents defined by a spectrum of attributes: complexity of their environment, complexity of their goals, a user interface based on natural language, capability of acting'
# page_content='natural language, capability of acting independently from user supervision, the use of software tools or planning, and a control flow based on large language models.[31] A common hypothetical use'
# page_content='models.[31] A common hypothetical use case is automatically booking travel plans based on a prompted request.[32][33][34][35][36][37] Examples of AI agents include Devin AI, AutoGPT, and SIMA.[38]'
# page_content='Devin AI, AutoGPT, and SIMA.[38] Examples of AI agent frameworks include LangChain,[39][40] Microsoft AutoGen[40] and OpenAI Swarm.[41]'
# page_content='Proposed benefits include increased personal and economic productivity,[36][33] and liberation from tedious work.[34] Potential concerns include liability,[36][33][34] cybercrime,[36][32]'
# page_content='cybercrime,[36][32] philosophical ethical considerations,[36] AI safety[36] and AI alignment,[32][34] data privacy,[35][32] weakening of human oversight,[35][36][32][33] algorithmic bias,[35]'
# page_content='algorithmic bias,[35] compounding software errors,[32][38] the compounding effect of existing concerns about artificial intelligence,[32] unpredictability,[32] difficulty explaining decisions made by'
# page_content='difficulty explaining decisions made by an agentic system,[32] security vulnerabilities,[32][33] job displacement,[33] manipulation of users,[42] how to adapt legal systems to agents,[34]'
# page_content='to adapt legal systems to agents,[34] hallucinations,[37] high cost of use,[31] overfitting of benchmark datasets,[31] and lack of standardization in or reproducibility of agent evaluation'
# page_content='or reproducibility of agent evaluation frameworks.[31]'
# page_content='Hallerbach et al. discussed the application of agent-based approaches for the development and validation of automated driving systems via a digital twin of the vehicle-under-test and microscopic'
# page_content='the vehicle-under-test and microscopic traffic simulation based on independent agents.[43] Waymo has created a multi-agent simulation environment, Carcraft, to test algorithms for self-driving'
# page_content='to test algorithms for self-driving cars.[44][45] It simulates traffic interactions between human drivers, pedestrians and automated vehicles. People's behavior is imitated by artificial agents based'
# page_content='is imitated by artificial agents based on data of real human behavior. The basic idea of using agent-based modeling to understand self-driving cars was discussed as early as 2003.[46]'
# page_content='A large language model (LLM) is a type of machine learning model designed for natural language processing tasks such as language generation. LLMs are language models with many parameters, and are'
# page_content='models with many parameters, and are trained with self-supervised learning on a vast amount of text.'
# page_content='The largest and most capable LLMs are generative pretrained transformers (GPTs). Modern models can be fine-tuned for specific tasks or guided by prompt engineering.[1] These models acquire predictive'
# page_content='These models acquire predictive power regarding syntax, semantics, and ontologies[2] inherent in human language corpora, but they also inherit inaccuracies and biases present in the data they are'
# page_content='and biases present in the data they are trained in.[3]'
# page_content='Before 2017, there were a few language models that were large as compared to capacities then available. In the 1990s, the IBM alignment models pioneered statistical language modelling. A smoothed'
# page_content='language modelling. A smoothed n-gram model in 2001 trained on 0.3 billion words achieved state-of-the-art perplexity at the time.[4] In the 2000s, as Internet use became prevalent, some researchers'
# page_content='use became prevalent, some researchers constructed Internet-scale language datasets ("web as corpus"[5]), upon which they trained statistical language models.[6][7] In 2009, in most language'
# page_content='models.[6][7] In 2009, in most language processing tasks, statistical language models dominated over symbolic language models, as they can usefully ingest large datasets.[8]'
# page_content='After neural networks became dominant in image processing around 2012,[9] they were applied to language modelling as well. Google converted its translation service to Neural Machine Translation in'
# page_content='to Neural Machine Translation in 2016. As it was before transformers, it was done by seq2seq deep LSTM networks.'
# page_content='At the 2017 NeurIPS conference, Google researchers introduced the transformer architecture in their landmark paper "Attention Is All You Need". This paper's goal was to improve upon 2014 seq2seq'
# page_content='goal was to improve upon 2014 seq2seq technology,[10] and was based mainly on the attention mechanism developed by Bahdanau et al. in 2014.[11] The following year in 2018, BERT was introduced and'
# page_content='year in 2018, BERT was introduced and quickly became "ubiquitous".[12] Though the original transformer has both encoder and decoder blocks, BERT is an encoder-only model.'
# page_content='Academic and research usage of BERT began to decline in 2023, following rapid improvements in the abilities of decoder-only models (such as GPT) to solve tasks via prompting.[13]'
# page_content='Although decoder-only GPT-1 was introduced in 2018, it was GPT-2 in 2019 that caught widespread attention because OpenAI at first deemed it too powerful to release publicly, out of fear of malicious'
# page_content='publicly, out of fear of malicious use.[14] GPT-3 in 2020 went a step further and as of 2024[update] is available only via API with no offering of downloading the model to execute locally. But it was'
# page_content='model to execute locally. But it was the 2022 consumer-facing browser-based ChatGPT that captured the imaginations of the general population and caused some media hype and online buzz.[15] The 2023'
# page_content='hype and online buzz.[15] The 2023 GPT-4 was praised for its increased accuracy and as a "holy grail" for its multimodal capabilities.[16] OpenAI did not reveal the high-level architecture and the'
# page_content='the high-level architecture and the number of parameters of GPT-4. The release of ChatGPT led to an uptick in LLM usage across several research subfields of computer science, including robotics,'
# page_content='computer science, including robotics, software engineering, and societal impact work.[17]'
# page_content='Competing language models have for the most part been attempting to equal the GPT series, at least in terms of number of parameters.[18]'
# page_content='Since 2022, source-available models have been gaining popularity, especially at first with BLOOM and LLaMA, though both have restrictions on the field of use. Mistral AI's models Mistral 7B and'
# page_content='use. Mistral AI's models Mistral 7B and Mixtral 8x7b have the more permissive Apache License. As of June 2024[update], The Instruction fine tuned variant of the Llama 3 70 billion parameter model is'
# page_content='Llama 3 70 billion parameter model is the most powerful open LLM according to the LMSYS Chatbot Arena Leaderboard, being more powerful than GPT-3.5 but not as powerful as GPT-4.[19]'
# page_content='Since 2023, many LLMs have been trained to be multimodal, having the ability to also process or generate other types of data, such as images or audio. These LLMs are also called large multimodal'
# page_content='LLMs are also called large multimodal models (LMMs).[20]'
# page_content='As of 2024, the largest and most capable models are all based on the transformer architecture. Some recent implementations are based on other architectures, such as recurrent neural network variants'
# page_content='as recurrent neural network variants and Mamba (a state space model).[21][22][23]'
# page_content='As machine learning algorithms process numbers rather than text, the text must be converted to numbers. In the first step, a vocabulary is decided upon, then integer indices are arbitrarily but'
# page_content='integer indices are arbitrarily but uniquely assigned to each vocabulary entry, and finally, an embedding is associated to the integer index. Algorithms include byte-pair encoding (BPE) and'
# page_content='include byte-pair encoding (BPE) and WordPiece. There are also special tokens serving as control characters, such as [MASK] for masked-out token (as used in BERT), and [UNK] ("unknown") for'
# page_content='in BERT), and [UNK] ("unknown") for characters not appearing in the vocabulary. Also, some special symbols are used to denote special text formatting. For example, "Ġ" denotes a preceding whitespace'
# page_content='"Ġ" denotes a preceding whitespace in RoBERTa and GPT. "##" denotes continuation of a preceding word in BERT.[24]'
# page_content='For example, the BPE tokenizer used by GPT-3 (Legacy) would split tokenizer: texts -> series of numerical "tokens" as'
# page_content='Tokenization also compresses the datasets. Because LLMs generally require input to be an array that is not jagged, the shorter texts must be "padded" until they match the length of the longest one.'
# page_content='match the length of the longest one. How many tokens are, on average, needed per word depends on the language of the dataset.[25][26]'
# page_content='As an example, consider a tokenizer based on byte-pair encoding. In the first step, all unique characters (including blanks and punctuation marks) are treated as an initial set of n-grams (i.e.'
# page_content='as an initial set of n-grams (i.e. initial set of uni-grams). Successively the most frequent pair of adjacent characters is merged into a bi-gram and all instances of the pair are replaced by it. All'
# page_content='of the pair are replaced by it. All occurrences of adjacent pairs of (previously merged) n-grams that most frequently occur together are then again merged into even lengthier n-gram, until a'
# page_content='into even lengthier n-gram, until a vocabulary of prescribed size is obtained (in case of GPT-3, the size is 50257).[27] After a tokenizer is trained, any text can be tokenized by it, as long as it'
# page_content='can be tokenized by it, as long as it does not contain characters not appearing in the initial-set of uni-grams.[28]'
# page_content='A token vocabulary based on the frequencies extracted from mainly English corpora uses as few tokens as possible for an average English word. An average word in another language encoded by such an'
# page_content='in another language encoded by such an English-optimized tokenizer is however split into suboptimal amount of tokens. GPT-2 tokenizer can use up to 15 times more tokens per word for some languages,'
# page_content='tokens per word for some languages, for example for the Shan language from Myanmar. Even more widespread languages such as Portuguese and German have "a premium of 50%" compared to English.[29]'
# page_content='Greedy tokenization also causes subtle problems with text completion.[30]'
# page_content='In the context of training LLMs, datasets are typically cleaned by removing low-quality, duplicated, or toxic data.[31] Cleaned datasets can increase training efficiency and lead to improved'
# page_content='efficiency and lead to improved downstream performance.[32][33] A trained LLM can be used to clean datasets for training a further LLM.[34]'
# page_content='With the increasing proportion of LLM-generated content on the web, data cleaning in the future may include filtering out such content. LLM-generated content can pose a problem if the content is'
# page_content='can pose a problem if the content is similar to human text (making filtering difficult) but of lower quality (degrading performance of models trained on it).[35]'
# page_content='Training of largest language models might need more linguistic data than naturally available, or that the naturally occurring data is of insufficient quality. In these cases, synthetic data might be'
# page_content='In these cases, synthetic data might be used. Microsoft's Phi series of LLMs is trained on textbook-like data generated by another LLM.[36]'
# page_content='Reinforcement learning from human feedback (RLHF) through algorithms, such as proximal policy optimization, is used to further fine-tune a model based on a dataset of human preferences.[37]'
# page_content='Using "self-instruct" approaches, LLMs have been able to bootstrap correct responses, replacing any naive responses, starting from human-generated corrections of a few cases. For example, in the'
# page_content='of a few cases. For example, in the instruction "Write an essay about the main themes represented in Hamlet," an initial naive completion might be "If you submit the essay after March 17, your grade'
# page_content='the essay after March 17, your grade will be reduced by 10% for each day of delay," based on the frequency of this textual sequence in the corpus.[38]'
# page_content='The largest LLM may be too expensive to train and use directly. For such models, mixture of experts (MoE) can be applied, a line of research pursued by Google researchers since 2017 to train models'
# page_content='researchers since 2017 to train models reaching up to 1 trillion parameters.[39][40][41]'
# page_content='Most results previously achievable only by (costly) fine-tuning, can be achieved through prompt engineering, although limited to the scope of a single conversation (more precisely, limited to the'
# page_content='(more precisely, limited to the scope of a context window).[42]'
# page_content='In order to find out which tokens are relevant to each other within the scope of the context window, the attention mechanism calculates "soft" weights for each token, more precisely for its'
# page_content='for each token, more precisely for its embedding, by using multiple attention heads, each with its own "relevance" for calculating its own soft weights. For example, the small (i.e. 117M parameter'
# page_content='example, the small (i.e. 117M parameter sized) GPT-2 model has had twelve attention heads and a context window of only 1k tokens.[44] In its medium version it has 345M parameters and contains 24'
# page_content='it has 345M parameters and contains 24 layers, each with 12 attention heads. For the training with gradient descent a batch size of 512 was utilized.[28]'
# page_content='The largest models, such as Google's Gemini 1.5, presented in February 2024, can have a context window sized up to 1 million (context window of 10 million was also "successfully tested").[45] Other'
# page_content='also "successfully tested").[45] Other models with large context windows includes Anthropic's Claude 2.1, with a context window of up to 200k tokens.[46] Note that this maximum refers to the number'
# page_content='that this maximum refers to the number of input tokens and that the maximum number of output tokens differs from the input and is often smaller. For example, the GPT-4 Turbo model has a maximum'
# page_content='the GPT-4 Turbo model has a maximum output of 4096 tokens.[47]'
# page_content='Length of a conversation that the model can take into account when generating its next answer is limited by the size of a context window, as well. If the length of a conversation, for example with'
# page_content='of a conversation, for example with ChatGPT, is longer than its context window, only the parts inside the context window are taken into account when generating the next answer, or the model needs to'
# page_content='the next answer, or the model needs to apply some algorithm to summarize the too distant parts of conversation.'
# page_content='The shortcomings of making a context window larger include higher computational cost and possibly diluting the focus on local context, while making it smaller can cause a model to miss an important'
# page_content='can cause a model to miss an important long-range dependency. Balancing them are a matter of experimentation and domain-specific considerations.'
# page_content='A model may be pre-trained either to predict how the segment continues, or what is missing in the segment, given a segment from its training dataset.[48] It can be either'
# page_content='Models may be trained on auxiliary tasks which test their understanding of the data distribution, such as Next Sentence Prediction (NSP), in which pairs of sentences are presented and the model must'
# page_content='are presented and the model must predict whether they appear consecutively in the training corpus.[49] During training, regularization loss is also used to stabilize training. However regularization'
# page_content='training. However regularization loss is usually not used during testing and evaluation.'
# page_content='Substantial infrastructure is necessary for training the largest models.[50][51][52]'
# page_content='The qualifier "large" in "large language model" is inherently vague, as there is no definitive threshold for the number of parameters required to qualify as "large". As time goes on, what was'
# page_content='as "large". As time goes on, what was previously considered "large" may evolve. GPT-1 of 2018 is usually considered the first LLM, even though it has only 0.117 billion parameters. The tendency'
# page_content='0.117 billion parameters. The tendency towards larger models is visible in the list of large language models.'
# page_content='Advances in software and hardware have reduced the cost substantially since 2020, such that in 2023 training of a 12-billion-parameter LLM computational cost is 72,300 A100-GPU-hours, while in 2020'
# page_content='is 72,300 A100-GPU-hours, while in 2020 the cost of training a 1.5-billion-parameter LLM (which was two orders of magnitude smaller than the state of the art in 2020) was between $80,000 and'
# page_content='art in 2020) was between $80,000 and $1,600,000.[53][54][55] Since 2020, large sums were invested in increasingly large models. For example, training of the GPT-2 (i.e. a 1.5-billion-parameters'
# page_content='GPT-2 (i.e. a 1.5-billion-parameters model) in 2019 cost $50,000, while training of the PaLM (i.e. a 540-billion-parameters model) in 2022 cost $8 million, and Megatron-Turing NLG 530B (in 2021) cost'
# page_content='Megatron-Turing NLG 530B (in 2021) cost around $11 million.[56]'
# page_content='For Transformer-based LLM, training cost is much higher than inference cost. It costs 6 FLOPs per parameter to train on one token, whereas it costs 1 to 2 FLOPs per parameter to infer on one'
# page_content='2 FLOPs per parameter to infer on one token.[57]'
# page_content='There are certain tasks that, in principle, cannot be solved by any LLM, at least not without the use of external tools or additional software. An example of such a task is responding to the user's'
# page_content='such a task is responding to the user's input '354 * 139 = ', provided that the LLM has not already encountered a continuation of this calculation in its training corpus.[dubious – discuss] In such'
# page_content='corpus.[dubious – discuss] In such cases, the LLM needs to resort to running program code that calculates the result, which can then be included in its response.[dubious – discuss]: Another example'
# page_content='– discuss]: Another example is "What is the time now? It is ", where a separate program interpreter would need to execute a code to get system time on the computer, so that the LLM can include it in'
# page_content='so that the LLM can include it in its reply.[58][59] This basic strategy can be sophisticated with multiple attempts of generated programs, and other sampling strategies.[60]'
# page_content='Generally, in order to get an LLM to use tools, one must fine-tune it for tool-use. If the number of tools is finite, then fine-tuning may be done just once. If the number of tools can grow'
# page_content='once. If the number of tools can grow arbitrarily, as with online API services, then the LLM can be fine-tuned to be able to read API documentation and call API correctly.[61][62]'
# page_content='A simpler form of tool use is retrieval-augmented generation: the augmentation of an LLM with document retrieval. Given a query, a document retriever is called to retrieve the most relevant'
# page_content='is called to retrieve the most relevant documents. This is usually done by encoding the query and the documents into vectors, then finding the documents with vectors (usually stored in a vector'
# page_content='vectors (usually stored in a vector database) most similar to the vector of the query. The LLM then generates an output based on both the query and context included from the retrieved documents.[63]'
# page_content='An LLM is typically not an autonomous agent by itself, as it lacks the ability to interact with dynamic environments, recall past behaviors, and plan future actions, but can be transformed into one'
# page_content='but can be transformed into one by integrating modules like profiling, memory, planning, and action.[64]'
# page_content='The ReAct pattern, a portmanteau of "Reason + Act", constructs an agent out of an LLM, using the LLM as a planner. The LLM is prompted to "think out loud". Specifically, the language model is'
# page_content='Specifically, the language model is prompted with a textual description of the environment, a goal, a list of possible actions, and a record of the actions and observations so far. It generates one'
# page_content='observations so far. It generates one or more thoughts before generating an action, which is then executed in the environment.[65] The linguistic description of the environment given to the LLM'
# page_content='of the environment given to the LLM planner can even be the LaTeX code of a paper describing the environment.[66]'
# page_content='In the DEPS ("Describe, Explain, Plan and Select") method, an LLM is first connected to the visual world via image descriptions, then it is prompted to produce plans for complex tasks and behaviors'
# page_content='plans for complex tasks and behaviors based on its pretrained knowledge and environmental feedback it receives.[67]'
# page_content='The Reflexion method[68] constructs an agent that learns over multiple episodes. At the end of each episode, the LLM is given the record of the episode, and prompted to think up "lessons learned",'
# page_content='prompted to think up "lessons learned", which would help it perform better at a subsequent episode. These "lessons learned" are given to the agent in the subsequent episodes.[citation needed]'
# page_content='Monte Carlo tree search can use an LLM as rollout heuristic. When a programmatic world model is not available, an LLM can also be prompted with a description of the environment to act as world'
# page_content='of the environment to act as world model.[69]'
# page_content='For open-ended exploration, an LLM can be used to score observations for their "interestingness", which can be used as a reward signal to guide a normal (non-LLM) reinforcement learning agent.[70]'
# page_content='reinforcement learning agent.[70] Alternatively, it can propose increasingly difficult tasks for curriculum learning.[71] Instead of outputting individual actions, an LLM planner can also construct'
# page_content='an LLM planner can also construct "skills", or functions for complex action sequences. The skills can be stored and later invoked, allowing increasing levels of abstraction in planning.[71]'
# page_content='LLM-powered agents can keep a long-term memory of its previous contexts, and the memory can be retrieved in the same way as Retrieval Augmented Generation. Multiple such agents can interact'
# page_content='Multiple such agents can interact socially.[72]'
# page_content='Typically, LLMs are trained with single- or half-precision floating point numbers (float32 and float16). One float16 has 16 bits, or 2 bytes, and so one billion parameters require 2 gigabytes. The'
# page_content='parameters require 2 gigabytes. The largest models typically have 100 billion parameters, requiring 200 gigabytes to load, which places them outside the range of most consumer electronics.[73]'
# page_content='Post-training quantization[74] aims to decrease the space requirement by lowering precision of the parameters of a trained model, while preserving most of its performance.[75][76] The simplest form'
# page_content='performance.[75][76] The simplest form of quantization simply truncates all numbers to a given number of bits. It can be improved by using a different quantization codebook per layer. Further'
# page_content='codebook per layer. Further improvement can be done by applying different precisions to different parameters, with higher precision for particularly important parameters ("outlier weights").[77] See'
# page_content='parameters ("outlier weights").[77] See [78] for a visual guide.'
# page_content='While quantized models are typically frozen, and only pre-quantized models are fine-tuned, quantized models can still be fine-tuned.[79]'
# page_content='Multimodality means "having several modalities", and a "modality" refers to a type of input or output, such as video, image, audio, text, proprioception, etc.[80] There have been many AI models'
# page_content='etc.[80] There have been many AI models trained specifically to ingest one modality and output another modality, such as AlexNet for image to label,[81] visual question answering for image-text to'
# page_content='question answering for image-text to text,[82] and speech recognition for speech to text.'
# page_content='A common method to create multimodal models out of an LLM is to "tokenize" the output of a trained encoder. Concretely, one can construct an LLM that can understand images as follows: take a trained'
# page_content='images as follows: take a trained LLM, and take a trained image encoder'
# page_content='E
#
#
# {\displaystyle E}
#
# . Make a small multilayered perceptron
#
#
#
# f
#
#
# {\displaystyle f}
#
# , so that for any image
#
#
#
# y
#
#
# {\displaystyle y}
#
# , the post-processed vector
#
#
#
# f
# (
# E
# (
# y
# )
# )'
# page_content='f
# (
# E
# (
# y
# )
# )
#
#
# {\displaystyle f(E(y))}'
# page_content='has the same dimensions as an encoded token. That is an "image token". Then, one can interleave text tokens and image tokens. The compound model is then fine-tuned on an image-text dataset. This'
# page_content='on an image-text dataset. This basic construction can be applied with more sophistication to improve the model. The image encoder may be frozen to improve stability.[83]'
# page_content='Flamingo demonstrated the effectiveness of the tokenization method, finetuning a pair of pretrained language model and image encoder to perform better on visual question answering than models trained'
# page_content='question answering than models trained from scratch.[84] Google PaLM model was fine-tuned into a multimodal model PaLM-E using the tokenization method, and applied to robotic control.[85] LLaMA'
# page_content='applied to robotic control.[85] LLaMA models have also been turned multimodal using the tokenization method, to allow image inputs,[86] and video inputs.[87]'
# page_content='GPT-4 can use both text and image as inputs[88] (although the vision component was not released to the public until GPT-4V[89]); Google DeepMind's Gemini is also multimodal.[90]  Mistral introduced'
# page_content='multimodal.[90]  Mistral introduced its own multimodel Pixtral 12B model in September 2024.[91]'
# page_content='The performance of an LLM after pretraining largely depends on the:'
# page_content='"Scaling laws" are empirical statistical laws that predict LLM performance based on such factors. One particular scaling law ("Chinchilla scaling") for LLM autoregressively trained for one epoch,'
# page_content='autoregressively trained for one epoch, with a log-log learning rate schedule, states that:[92]'
# page_content='{
#
#
#
# C
# =
#
# C
#
# 0
#
#
# N
# D
#
#
#
#
# L
# =
#
#
# A
#
# N
#
# α
#
#
#
#
# +
#
#
# B
#
# D
#
# β
#
#
#
#
# +
#
# L
#
# 0
#
#
#
#
#
#
#
#
#
#
# {\displaystyle {\begin{cases}C=C_{0}ND\\[6pt]L={\frac {A}{N^{\alpha }}}+{\frac {B}{D^{\beta }}}+L_{0}\end{cases}}}'
# page_content='where the variables are
#
# and the statistical hyper-parameters are'
# page_content='Performance of bigger models on various tasks, when plotted on a log-log scale, appears as a linear extrapolation of performance achieved by smaller models. However, this linearity may be punctuated'
# page_content='this linearity may be punctuated by "break(s)"[93] in the scaling law, where the slope of the line changes abruptly, and where larger models acquire "emergent abilities".[42][94] They arise from the'
# page_content='abilities".[42][94] They arise from the complex interaction of the model's components and are not explicitly programmed or designed.[95]'
# page_content='Furthermore, recent research has demonstrated that AI systems, including large language models, can employ heuristic reasoning akin to human cognition. They balance between exhaustive logical'
# page_content='They balance between exhaustive logical processing and the use of cognitive shortcuts (heuristics), adapting their reasoning strategies to optimize between accuracy and effort. This behavior aligns'
# page_content='and effort. This behavior aligns with principles of resource-rational human cognition, as discussed in classical theories of bounded rationality and dual-process theory.[96]'
# page_content='The most intriguing among emergent abilities is in-context learning from example demonstrations.[97] In-context learning is involved in tasks, such as:'
# page_content='Schaeffer et. al. argue that the emergent abilities are not unpredictably acquired, but predictably acquired according to a smooth scaling law. The authors considered a toy statistical model of an'
# page_content='a toy statistical model of an LLM solving multiple-choice questions, and showed that this statistical model, modified to account for other types of tasks, applies to these tasks as well.[103]'
# page_content='Let
#
#
#
# x
#
#
# {\displaystyle x}
#
#  be the number of parameter count, and
#
#
#
# y
#
#
# {\displaystyle y}
#
#  be the performance of the model.'
# page_content='Large language models by themselves are black boxes, and it is not clear how they can perform linguistic tasks. There are several methods for understanding how LLM work.'
# page_content='Mechanistic interpretability aims to reverse-engineer LLM by discovering symbolic algorithms that approximate the inference performed by LLM. One example is Othello-GPT, where a small Transformer is'
# ...
# page_content='correspond to the generation of text or responses that seem syntactically sound, fluent, and natural but are factually incorrect, nonsensical, or unfaithful to the provided source input.[117]'
# page_content='to the provided source input.[117] Neuroscientist Terrence Sejnowski has argued that "The diverging opinions of experts on the intelligence of LLMs suggests that our old ideas based on natural'
# page_content='that our old ideas based on natural intelligence are inadequate".[108]'
# page_content='The matter of LLM's exhibiting intelligence or understanding has two main aspects – the first is how to model thought and language in a computer system, and the second is how to enable the computer'
# page_content='second is how to enable the computer system to generate human like language.[108] These aspects of language as a model of cognition have been developed in the field of cognitive linguistics. American'
# page_content='of cognitive linguistics. American linguist George Lakoff presented Neural Theory of Language (NTL)[118] as a computational basis for using language as a model of learning tasks and understanding.'
# page_content='of learning tasks and understanding. The NTL Model outlines how specific neural structures of the human brain shape the nature of thought and language and in turn what are the computational'
# page_content='and in turn what are the computational properties of such neural systems that can be applied to model thought and language in a computer system. After a framework for modeling language in a computer'
# page_content='for modeling language in a computer systems was established, the focus shifted to establishing frameworks for computer systems to generate language with acceptable grammar. In his 2014 book titled'
# page_content='grammar. In his 2014 book titled The Language Myth: Why Language Is Not An Instinct, British cognitive linguist and digital communication technologist Vyvyan Evans mapped out the role of'
# page_content='Vyvyan Evans mapped out the role of probabilistic context-free grammar (PCFG) in enabling NLP to model cognitive patterns and generate human like language.[119][120]'
# page_content='The canonical measure of the performance of an LLM is its perplexity on a given text corpus. Perplexity measures how well a model predicts the contents of a dataset; the higher the likelihood the'
# page_content='dataset; the higher the likelihood the model assigns to the dataset, the lower the perplexity. In mathematical terms, perplexity is the exponential of the average negative log likelihood per token.'
# page_content='log
# ⁡
# (
#
# Perplexity
#
# )
# =
# −
#
#
# 1
# N
#
#
#
# ∑
#
# i
# =
# 1
#
#
# N
#
#
# log
# ⁡
# (
# Pr
# (
#
#
# token
#
#
# i
#
#
# ∣
#
#
# context for token
#
#
# i
#
#
# )
# )'
# page_content='i
#
#
# ∣
#
#
# context for token
#
#
# i
#
#
# )
# )
#
#
# {\displaystyle \log({\text{Perplexity}})=-{\frac {1}{N}}\sum _{i=1}^{N}\log(\Pr({\text{token}}_{i}\mid {\text{context for token}}_{i}))}
#
#
#
# Here,
#
#
#
# N'
# page_content='Here,
#
#
#
# N
#
#
# {\displaystyle N}
#
#  is the number of tokens in the text corpus, and "context for token
#
#
#
# i
#
#
# {\displaystyle i}'
# page_content='i
#
#
# {\displaystyle i}
#
# " depends on the specific type of LLM. If the LLM is autoregressive, then "context for token
#
#
#
# i
#
#
# {\displaystyle i}
#
# " is the segment of text appearing before token
#
#
#
# i'
# page_content='i
#
#
# {\displaystyle i}
#
# . If the LLM is masked, then "context for token
#
#
#
# i
#
#
# {\displaystyle i}
#
# " is the segment of text surrounding token
#
#
#
# i
#
#
# {\displaystyle i}
#
# .'
# page_content='Because language models may overfit to training data, models are usually evaluated by their perplexity on a test set.[49] This evaluation is potentially problematic for larger models which, as they'
# page_content='for larger models which, as they are trained on increasingly large corpora of text, are increasingly likely to inadvertently include portions of any given test set.[1]'
# page_content='In information theory, the concept of entropy is intricately linked to perplexity, a relationship notably established by Claude Shannon.[121] This relationship is mathematically expressed as'
# page_content='Entropy
#
# =
#
# log
#
# 2
#
#
# ⁡
# (
#
# Perplexity
#
# )
#
#
# {\displaystyle {\text{Entropy}}=\log _{2}({\text{Perplexity}})}
#
# .'
# page_content='Entropy, in this context, is commonly quantified in terms of bits per word (BPW) or bits per character (BPC), which hinges on whether the language model utilizes word-based or character-based'
# page_content='utilizes word-based or character-based tokenization.'
# page_content='Notably, in the case of larger language models that predominantly employ sub-word tokenization, bits per token (BPT) emerges as a seemingly more appropriate measure. However, due to the variance in'
# page_content='However, due to the variance in tokenization methods across different Large Language Models (LLMs), BPT does not serve as a reliable metric for comparative analysis among diverse models. To convert'
# page_content='among diverse models. To convert BPT into BPW, one can multiply it by the average number of tokens per word.'
# page_content='In the evaluation and comparison of language models, cross-entropy is generally the preferred metric over entropy. The underlying principle is that a lower BPW is indicative of a model's enhanced'
# page_content='BPW is indicative of a model's enhanced capability for compression. This, in turn, reflects the model's proficiency in making accurate predictions.'
# page_content='A large number of testing datasets and benchmarks have also been developed to evaluate the capabilities of language models on more specific downstream tasks. Tests may be designed to evaluate a'
# page_content='Tests may be designed to evaluate a variety of capabilities, including general knowledge, commonsense reasoning, and mathematical problem-solving.'
# page_content='One broad category of evaluation dataset is question answering datasets, consisting of pairs of questions and correct answers, for example, ("Have the San Jose Sharks won the Stanley Cup?",'
# page_content='San Jose Sharks won the Stanley Cup?", "No").[122] A question answering task is considered "open book" if the model's prompt includes text from which the expected answer can be derived (for example,'
# page_content='answer can be derived (for example, the previous question could be adjoined with some text which includes the sentence "The Sharks have advanced to the Stanley Cup finals once, losing to the'
# page_content='Stanley Cup finals once, losing to the Pittsburgh Penguins in 2016."[122]). Otherwise, the task is considered "closed book", and the model must draw on knowledge retained during training.[123] Some'
# page_content='retained during training.[123] Some examples of commonly used question answering datasets include TruthfulQA, Web Questions, TriviaQA, and SQuAD.[123]'
# page_content='Evaluation datasets may also take the form of text completion, having the model select the most likely word or sentence to complete a prompt, for example: "Alice was friends with Bob. Alice went to'
# page_content='was friends with Bob. Alice went to visit her friend, ____".[1]'
# page_content='Some composite benchmarks have also been developed which combine a diversity of different evaluation datasets and tasks. Examples include GLUE, SuperGLUE, MMLU, BIG-bench, and HELM.[121][123] OpenAI'
# page_content='BIG-bench, and HELM.[121][123] OpenAI has released tools for running composite benchmarks, but noted that the eval results are sensitive to the prompting method.[124][125] Some public datasets'
# page_content='method.[124][125] Some public datasets contain questions that are mislabeled, ambiguous, unanswerable, or otherwise of low-quality, which can be cleaned to give more reliable benchmark scores.[126]'
# page_content='It was previously standard to report results on a heldout portion of an evaluation dataset after doing supervised fine-tuning on the remainder. It is now more common to evaluate a pre-trained model'
# page_content='common to evaluate a pre-trained model directly through prompting techniques, though researchers vary in the details of how they formulate prompts for particular tasks, particularly with respect to'
# page_content='tasks, particularly with respect to how many examples of solved tasks are adjoined to the prompt (i.e. the value of n in n-shot prompting).'
# page_content='Because of the rapid pace of improvement of large language models, evaluation benchmarks have suffered from short lifespans, with state of the art models quickly "saturating" existing benchmarks,'
# page_content='"saturating" existing benchmarks, exceeding the performance of human annotators, leading to efforts to replace or augment the benchmark with more challenging tasks.[127] In addition, there are cases'
# page_content='In addition, there are cases of "shortcut learning" wherein AIs sometimes "cheat" on multiple-choice tests by using statistical correlations in superficial test question wording in order to guess the'
# page_content='question wording in order to guess the correct responses, without necessarily understanding the actual question being asked.[108]'
# page_content='Some datasets have been constructed adversarially, focusing on particular problems on which extant language models seem to have unusually poor performance compared to humans. One example is the'
# page_content='compared to humans. One example is the TruthfulQA dataset, a question answering dataset consisting of 817 questions which language models are susceptible to answering incorrectly by mimicking'
# page_content='to answering incorrectly by mimicking falsehoods to which they were repeatedly exposed during training. For example, an LLM may answer "No" to the question "Can you teach an old dog new tricks?"'
# page_content='"Can you teach an old dog new tricks?" because of its exposure to the English idiom you can't teach an old dog new tricks, even though this is not literally true.[128]'
# page_content='Another example of an adversarial evaluation dataset is Swag and its successor, HellaSwag, collections of problems in which one of multiple options must be selected to complete a text passage. The'
# page_content='to complete a text passage. The incorrect completions were generated by sampling from a language model and filtering with a set of classifiers. The resulting problems are trivial for humans but at'
# page_content='problems are trivial for humans but at the time the datasets were created state of the art language models had poor accuracy on them. For example:'
# page_content='We see a fitness center sign. We then see a man talking to the camera and sitting and laying on a exercise ball. The man...'
# page_content='a) demonstrates how to increase efficient exercise work by running up and down balls.
# b) moves all his arms and legs and builds up a lot of muscle.'
# page_content='c) then plays the ball and we see a graphics and hedge trimming demonstration.
# d) performs sit ups while on the ball and talking.[129]'
# page_content='BERT selects b) as the most likely completion, though the correct answer is d).[129]'
# page_content='In 2023, Nature Biomedical Engineering wrote that "it is no longer possible to accurately distinguish" human-written text from text created by large language models, and that "It is all but certain'
# page_content='models, and that "It is all but certain that general-purpose large language models will rapidly proliferate... It is a rather safe bet that they will change many industries over time."[130] Goldman'
# page_content='industries over time."[130] Goldman Sachs suggested in 2023 that generative language AI could increase global GDP by 7% in the next ten years, and could expose to automation 300 million jobs'
# page_content='expose to automation 300 million jobs globally.[131][132]'
# page_content='Memorization is an emergent behavior in LLMs in which long strings of text are occasionally output verbatim from training data, contrary to typical behavior of traditional artificial neural nets.'
# page_content='of traditional artificial neural nets. Evaluations of controlled LLM output measure the amount memorized from training data (focused on GPT-2-series models) as variously over 1% for exact'
# page_content='models) as variously over 1% for exact duplicates[133] or up to about 7%.[134]'
# page_content='A 2023 study showed that when ChatGPT 3.5 turbo was prompted to repeat the same word indefinitely, after a few hundreds of repetitions, it would start outputting excerpts from its training data.[135]'
# page_content='Some commenters expressed concern over accidental or deliberate creation of misinformation, or other forms of misuse.[136] For example, the availability of large language models could reduce the'
# page_content='large language models could reduce the skill-level required to commit bioterrorism; biosecurity researcher Kevin Esvelt has suggested that LLM creators should exclude from their training data papers'
# page_content='exclude from their training data papers on creating or enhancing pathogens.[137]'
# page_content='The potential presence of "sleeper agents" within LLM models is another emerging security concern. These are hidden functionalities built into the model that remain dormant until triggered by a'
# page_content='remain dormant until triggered by a specific event or condition. Upon activation, the LLM deviates from its expected behavior to make insecure actions.[138]'
# page_content='LLM applications accessible to the public, like ChatGPT or Claude, typically incorporate safety measures designed to filter out harmful content. However, implementing these controls effectively has'
# page_content='these controls effectively has proven challenging. For instance, a 2023 study[139] proposed a method for circumventing LLM safety systems. Similarly, Yongge Wang[140] illustrated in 2024 how a'
# page_content='Wang[140] illustrated in 2024 how a potential criminal could potentially bypass ChatGPT 4o's safety controls to obtain information on establishing a drug trafficking operation.'
# page_content='While LLMs have shown remarkable capabilities in generating human-like text, they are susceptible to inheriting and amplifying biases present in their training data. This can manifest in skewed'
# page_content='data. This can manifest in skewed representations or unfair treatment of different demographics, such as those based on race, gender, language, and cultural groups.[141] Since English data is'
# page_content='groups.[141] Since English data is overrepresented in current large language models' training data, it may also downplay non-English views.[142]'
# page_content='AI models can reinforce a wide range of stereotypes, including those based on gender, ethnicity, age, nationality, religion, or occupation. This can lead to outputs that unfairly generalize or'
# page_content='to outputs that unfairly generalize or caricature groups of people, sometimes in harmful or derogatory ways.[143]'
# page_content='Notably, gender bias refers to the tendency of these models to produce outputs that are unfairly prejudiced towards one gender over another. This bias typically arises from the data on which these'
# page_content='arises from the data on which these models are trained. Large language models often assign roles and characteristics based on traditional gender norms.[141] For example, it might associate nurses or'
# page_content='example, it might associate nurses or secretaries predominantly with women and engineers or CEOs with men.[144]'
# page_content='Political bias refers to the tendency of algorithms to systematically favor certain political viewpoints, ideologies, or outcomes over others. Language models may also exhibit political biases. Since'
# page_content='also exhibit political biases. Since the training data includes a wide range of political opinions and coverage, the models might generate responses that lean towards particular political ideologies'
# page_content='towards particular political ideologies or viewpoints, depending on the prevalence of those views in the data.[145]'

# %%
docs
# Out:
# [Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='In intelligence and artificial intelligence, an intelligent agent (IA) is an agent that perceives its environment, takes actions autonomously in order to achieve goals, and may improve its performance'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='goals, and may improve its performance with learning or acquiring knowledge.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='An intelligent agent may be simple or complex: A thermostat or other control system is considered an example of an intelligent agent, as is a human being, as is any system that meets the definition,'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='any system that meets the definition, such as a firm, a state, or a biome.[1]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Leading AI textbooks define "artificial intelligence" as the "study and design of intelligent agents", a definition that considers goal-directed behavior to be the essence of intelligence.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='to be the essence of intelligence. Goal-directed agents are also described using a term borrowed from economics, "rational agent".[1]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='An agent has an "objective function" that encapsulates all the IA\'s goals. Such an agent is designed to create and execute whatever plan will, upon completion, maximize the expected value of the'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='maximize the expected value of the objective function.[2]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='For example, a reinforcement learning agent has a "reward function" that allows the programmers to shape the IA\'s desired behavior,[3] and an evolutionary algorithm\'s behavior is shaped by a "fitness'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='behavior is shaped by a "fitness function".[4]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Intelligent agents in artificial intelligence are closely related to agents in economics, and versions of the intelligent agent paradigm are studied in cognitive science, ethics, and the philosophy'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='science, ethics, and the philosophy of practical reason, as well as in many interdisciplinary socio-cognitive modeling and computer social simulations.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Intelligent agents are often described schematically as an abstract functional system similar to a computer program.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Abstract descriptions of intelligent agents are called abstract intelligent agents (AIA) to distinguish them from their real-world implementations.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='An autonomous intelligent agent is designed to function in the absence of human intervention. Intelligent agents are also closely related to software agents. An autonomous computer program that'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='An autonomous computer program that carries out tasks on behalf of users.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Artificial Intelligence: A Modern Approach[5][6][2] defines an "agent" as'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='"Anything that can be viewed as perceiving its environment through sensors and acting upon that environment through actuators"\nIt defines a "rational agent" as:'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='"An agent that acts so as to maximize the expected value of a performance measure based on past experience and knowledge."\nIt also defines the field of "artificial intelligence research" as:'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='"The study and design of rational agents"'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Padgham & Winikoff (2005) agree that an intelligent agent is situated in an environment and responds in a timely (though not necessarily real-time) manner to changes in the environment. However,'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='to changes in the environment. However, intelligent agents must also proactively pursue goals in a flexible and robust way.[a] Optional desiderata include that the agent be rational, and that the'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='the agent be rational, and that the agent be capable of belief-desire-intention analysis.[7]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Kaplan and Haenlein define artificial intelligence as "a system\'s ability to correctly interpret external data, to learn from such data, and to use those learnings to achieve specific goals and tasks'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='to achieve specific goals and tasks through flexible adaptation".[8] This definition is closely related to that of an intelligent agent.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Philosophically, this definition of artificial intelligence avoids several lines of criticism. Unlike the Turing test, it does not refer to human intelligence in any way. Thus, there is no need to'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='in any way. Thus, there is no need to discuss if it is "real" vs "simulated" intelligence (i.e., "synthetic" vs "artificial" intelligence) and does not indicate that such a machine has a mind,'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='that such a machine has a mind, consciousness or true understanding. It seems not to imply John Searle\'s "strong AI hypothesis". It also doesn\'t attempt to draw a sharp dividing line between'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='to draw a sharp dividing line between behaviors that are "intelligent" and behaviors that are "unintelligent"—programs need only be measured in terms of their objective function.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='More importantly, it has a number of practical advantages that have helped move AI research forward. It provides a reliable and scientific way to test programs; researchers can directly compare or'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='researchers can directly compare or even combine different approaches to isolated problems, by asking which agent is best at maximizing a given "goal function".'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='It also gives them a common language to communicate with other fields—such as mathematical optimization (which is defined in terms of "goals") or economics (which uses the same definition of a'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='(which uses the same definition of a "rational agent").[9]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='An agent that is assigned an explicit "goal function" is considered more intelligent if it consistently takes actions that successfully maximize its programmed goal function.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The goal can be simple: 1 if the IA wins a game of Go, 0 otherwise.\n\nOr the goal can be complex: Perform actions mathematically similar to ones that succeeded in the past.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The "goal function" encapsulates all of the goals the agent is driven to act on; in the case of rational agents, the function also encapsulates the acceptable trade-offs between accomplishing'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='trade-offs between accomplishing conflicting goals.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Terminology varies. For example, some agents seek to maximize or minimize an "utility function", "objective function" or "loss function".[6][2]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Goals can be explicitly defined or induced. If the AI is programmed for "reinforcement learning", it has a "reward function" that encourages some types of behavior and punishes others.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Alternatively, an evolutionary system can induce goals by using a "fitness function" to mutate and preferentially replicate high-scoring AI systems, similar to how animals evolved to innately desire'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='how animals evolved to innately desire certain goals such as finding food.[10]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Some AI systems, such as nearest-neighbor, instead of reason by analogy, these systems are not generally given goals, except to the degree that goals are implicit in their training data.[11] Such'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='in their training data.[11] Such systems can still be benchmarked if the non-goal system is framed as a system whose "goal" is to accomplish its narrow classification task.[12]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Systems that are not traditionally considered agents, such as knowledge-representation systems, are sometimes subsumed into the paradigm by framing them as agents that have a goal of (for example)'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='that have a goal of (for example) answering questions as accurately as possible; the concept of an "action" is here extended to encompass the "act" of giving an answer to a question. As an additional'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='answer to a question. As an additional extension, mimicry-driven systems can be framed as agents who are optimizing a "goal function" based on how closely the IA succeeds in mimicking the desired'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='IA succeeds in mimicking the desired behavior.[6][2] In the generative adversarial networks of the 2010s, an "encoder"/"generator" component attempts to mimic and improvise human text composition.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='and improvise human text composition. The generator is attempting to maximize a function encapsulating how well it can fool an antagonistic "predictor"/"discriminator" component.[13]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='While symbolic AI systems often accept an explicit goal function, the paradigm can also be applied to neural networks and to evolutionary computing. Reinforcement learning can generate intelligent'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='learning can generate intelligent agents that appear to act in ways intended to maximize a "reward function".[14] Sometimes, rather than setting the reward function to be directly equal to the'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='function to be directly equal to the desired benchmark evaluation function, machine learning programmers will use reward shaping to initially give the machine rewards for incremental progress in'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='rewards for incremental progress in learning.[15] Yann LeCun stated in 2018, "Most of the learning algorithms that people have come up with essentially consist of minimizing some objective'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='consist of minimizing some objective function."[16] AlphaZero chess had a simple objective function; each win counted as +1 point, and each loss counted as -1 point. An objective function for a'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='-1 point. An objective function for a self-driving car would have to be more complicated.[17] Evolutionary computing can evolve intelligent agents that appear to act in ways intended to maximize a'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='to act in ways intended to maximize a "fitness function" that influences how many descendants each agent is allowed to leave.[4]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The mathematical formalism of AIXI was proposed as a maximally intelligent agent in this paradigm.[18] However, AIXI is uncomputable. In the real world, an IA is constrained by finite time and'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='an IA is constrained by finite time and hardware resources, and scientists compete to produce algorithms that can achieve progressively higher scores on benchmark tests with existing hardware.[19]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='A simple agent program can be defined mathematically as a function f (called the "agent function")[20] which maps every possible percepts sequence to a possible action the agent can perform or to a'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='action the agent can perform or to a coefficient, feedback element, function or constant that affects eventual actions:'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Agent function is an abstract concept as it could incorporate various principles of decision making like calculation of utility of individual options, deduction over logic rules, fuzzy logic,'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='over logic rules, fuzzy logic, etc.[21]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The program agent, instead, maps every possible percept to an action.[22]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content="We use the term percept to refer to the agent's perceptional inputs at any given instant. In the following figures, an agent is anything that can be viewed as perceiving its environment through"),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='as perceiving its environment through sensors and acting upon that environment through actuators.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Russell & Norvig (2003) group agents into five classes based on their degree of perceived intelligence and capability:[23]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Simple reflex agents act only on the basis of the current percept, ignoring the rest of the percept history. The agent function is based on the condition-action rule: "if condition, then action".'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='This agent function only succeeds when the environment is fully observable. Some reflex agents can also contain information on their current state which allows them to disregard conditions whose'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='them to disregard conditions whose actuators are already triggered.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Infinite loops are often unavoidable for simple reflex agents operating in partially observable environments. If the agent can randomize its actions, it may be possible to escape from infinite loops.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='A model-based agent can handle partially observable environments. Its current state is stored inside the agent maintaining some kind of structure that describes the part of the world which cannot be'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='the part of the world which cannot be seen. This knowledge about "how the world works" is called a model of the world, hence the name "model-based agent".'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='A model-based reflex agent should maintain some sort of internal model that depends on the percept history and thereby reflects at least some of the unobserved aspects of the current state. Percept'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='aspects of the current state. Percept history and impact of action on the environment can be determined by using the internal model. It then chooses an action in the same way as reflex agent.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='An agent may also use models to describe and predict the behaviors of other agents in the environment.[24]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Goal-based agents further expand on the capabilities of the model-based agents, by using "goal" information. Goal information describes situations that are desirable. This provides the agent a way to'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='This provides the agent a way to choose among multiple possibilities, selecting the one which reaches a goal state. Search and planning are the subfields of artificial intelligence devoted to finding'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content="intelligence devoted to finding action sequences that achieve the agent's goals."),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Goal-based agents only distinguish between goal states and non-goal states. It is also possible to define a measure of how desirable a particular state is. This measure can be obtained through the'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='measure can be obtained through the use of a utility function which maps a state to a measure of the utility of the state. A more general performance measure should allow a comparison of different'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='should allow a comparison of different world states according to how well they satisfied the agent\'s goals. The term utility can be used to describe how "happy" the agent is.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='A rational utility-based agent chooses the action that maximizes the expected utility of the action outcomes - that is, what the agent expects to derive, on average, given the probabilities and'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='on average, given the probabilities and utilities of each outcome. A utility-based agent has to model and keep track of its environment, tasks that have involved a great deal of research on'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='involved a great deal of research on perception, representation, reasoning, and learning.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Learning has the advantage of allowing agents to initially operate in unknown environments and become more competent than their initial knowledge alone might allow. The most important distinction is'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The most important distinction is between the "learning element", responsible for making improvements, and the "performance element", responsible for selecting external actions.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The learning element uses feedback from the "critic" on how the agent is doing and determines how the performance element, or "actor", should be modified to do better in the future. The performance'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='better in the future. The performance element, previously considered the entire agent, takes in percepts and decides on actions.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='The last component of the learning agent is the "problem generator". It is responsible for suggesting actions that will lead to new and informative experiences.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Weiss (2013) defines four classes of agents:\n\nIn 2013, Alexander Wissner-Gross published a theory pertaining to Freedom and Intelligence for intelligent agents.[25][26]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Intelligent agents can be organized hierarchically into multiple "sub-agents". Intelligent sub-agents process and perform lower-level functions. Taken together, the intelligent agent and sub-agents'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='the intelligent agent and sub-agents create a complete system that can accomplish difficult tasks or goals with behaviors and responses that display a form of intelligence.'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Generally, an agent can be constructed by separating the body into the sensors and actuators, and so that it operates with a complex perception system that takes the description of the world as input'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='the description of the world as input for a controller and outputs commands to the actuator. However, a hierarchy of controller layers is often necessary to balance the immediate reaction desired for'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='the immediate reaction desired for low-level tasks and the slow reasoning about complex, high-level goals.[27]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='"Intelligent agent" is also often used as a vague term, sometimes synonymous with "virtual personal assistant".[28] Some 20th-century definitions characterize an agent as a program that aids a user'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='an agent as a program that aids a user or that acts on behalf of a user.[29] These examples are known as software agents, and sometimes an "intelligent software agent" (that is, a software agent with'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='agent" (that is, a software agent with intelligence) is referred to as an "intelligent agent".'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='According to Nikola Kasabov, IA systems should exhibit the following characteristics:[30]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='In the context of generative artificial intelligence, AI agents[31] (also known as compound AI systems,[31] agentic AI,[32][33][34] large action models,[32] or large agent models[32]) are agents'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='or large agent models[32]) are agents defined by a spectrum of attributes: complexity of their environment, complexity of their goals, a user interface based on natural language, capability of acting'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='natural language, capability of acting independently from user supervision, the use of software tools or planning, and a control flow based on large language models.[31] A common hypothetical use'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='models.[31] A common hypothetical use case is automatically booking travel plans based on a prompted request.[32][33][34][35][36][37] Examples of AI agents include Devin AI, AutoGPT, and SIMA.[38]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Devin AI, AutoGPT, and SIMA.[38] Examples of AI agent frameworks include LangChain,[39][40] Microsoft AutoGen[40] and OpenAI Swarm.[41]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Proposed benefits include increased personal and economic productivity,[36][33] and liberation from tedious work.[34] Potential concerns include liability,[36][33][34] cybercrime,[36][32]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='cybercrime,[36][32] philosophical ethical considerations,[36] AI safety[36] and AI alignment,[32][34] data privacy,[35][32] weakening of human oversight,[35][36][32][33] algorithmic bias,[35]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='algorithmic bias,[35] compounding software errors,[32][38] the compounding effect of existing concerns about artificial intelligence,[32] unpredictability,[32] difficulty explaining decisions made by'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='difficulty explaining decisions made by an agentic system,[32] security vulnerabilities,[32][33] job displacement,[33] manipulation of users,[42] how to adapt legal systems to agents,[34]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='to adapt legal systems to agents,[34] hallucinations,[37] high cost of use,[31] overfitting of benchmark datasets,[31] and lack of standardization in or reproducibility of agent evaluation'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='or reproducibility of agent evaluation frameworks.[31]'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='Hallerbach et al. discussed the application of agent-based approaches for the development and validation of automated driving systems via a digital twin of the vehicle-under-test and microscopic'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='the vehicle-under-test and microscopic traffic simulation based on independent agents.[43] Waymo has created a multi-agent simulation environment, Carcraft, to test algorithms for self-driving'),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content="to test algorithms for self-driving cars.[44][45] It simulates traffic interactions between human drivers, pedestrians and automated vehicles. People's behavior is imitated by artificial agents based"),
#  Document(metadata={'source': '../Knowledgebase/Intelligent_agent.txt'}, page_content='is imitated by artificial agents based on data of real human behavior. The basic idea of using agent-based modeling to understand self-driving cars was discussed as early as 2003.[46]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='A large language model (LLM) is a type of machine learning model designed for natural language processing tasks such as language generation. LLMs are language models with many parameters, and are'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='models with many parameters, and are trained with self-supervised learning on a vast amount of text.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='The largest and most capable LLMs are generative pretrained transformers (GPTs). Modern models can be fine-tuned for specific tasks or guided by prompt engineering.[1] These models acquire predictive'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='These models acquire predictive power regarding syntax, semantics, and ontologies[2] inherent in human language corpora, but they also inherit inaccuracies and biases present in the data they are'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='and biases present in the data they are trained in.[3]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Before 2017, there were a few language models that were large as compared to capacities then available. In the 1990s, the IBM alignment models pioneered statistical language modelling. A smoothed'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='language modelling. A smoothed n-gram model in 2001 trained on 0.3 billion words achieved state-of-the-art perplexity at the time.[4] In the 2000s, as Internet use became prevalent, some researchers'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='use became prevalent, some researchers constructed Internet-scale language datasets ("web as corpus"[5]), upon which they trained statistical language models.[6][7] In 2009, in most language'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='models.[6][7] In 2009, in most language processing tasks, statistical language models dominated over symbolic language models, as they can usefully ingest large datasets.[8]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='After neural networks became dominant in image processing around 2012,[9] they were applied to language modelling as well. Google converted its translation service to Neural Machine Translation in'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='to Neural Machine Translation in 2016. As it was before transformers, it was done by seq2seq deep LSTM networks.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='At the 2017 NeurIPS conference, Google researchers introduced the transformer architecture in their landmark paper "Attention Is All You Need". This paper\'s goal was to improve upon 2014 seq2seq'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='goal was to improve upon 2014 seq2seq technology,[10] and was based mainly on the attention mechanism developed by Bahdanau et al. in 2014.[11] The following year in 2018, BERT was introduced and'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='year in 2018, BERT was introduced and quickly became "ubiquitous".[12] Though the original transformer has both encoder and decoder blocks, BERT is an encoder-only model.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Academic and research usage of BERT began to decline in 2023, following rapid improvements in the abilities of decoder-only models (such as GPT) to solve tasks via prompting.[13]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Although decoder-only GPT-1 was introduced in 2018, it was GPT-2 in 2019 that caught widespread attention because OpenAI at first deemed it too powerful to release publicly, out of fear of malicious'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='publicly, out of fear of malicious use.[14] GPT-3 in 2020 went a step further and as of 2024[update] is available only via API with no offering of downloading the model to execute locally. But it was'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='model to execute locally. But it was the 2022 consumer-facing browser-based ChatGPT that captured the imaginations of the general population and caused some media hype and online buzz.[15] The 2023'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='hype and online buzz.[15] The 2023 GPT-4 was praised for its increased accuracy and as a "holy grail" for its multimodal capabilities.[16] OpenAI did not reveal the high-level architecture and the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='the high-level architecture and the number of parameters of GPT-4. The release of ChatGPT led to an uptick in LLM usage across several research subfields of computer science, including robotics,'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='computer science, including robotics, software engineering, and societal impact work.[17]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Competing language models have for the most part been attempting to equal the GPT series, at least in terms of number of parameters.[18]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="Since 2022, source-available models have been gaining popularity, especially at first with BLOOM and LLaMA, though both have restrictions on the field of use. Mistral AI's models Mistral 7B and"),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="use. Mistral AI's models Mistral 7B and Mixtral 8x7b have the more permissive Apache License. As of June\xa02024[update], The Instruction fine tuned variant of the Llama 3 70 billion parameter model is"),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Llama 3 70 billion parameter model is the most powerful open LLM according to the LMSYS Chatbot Arena Leaderboard, being more powerful than GPT-3.5 but not as powerful as GPT-4.[19]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Since 2023, many LLMs have been trained to be multimodal, having the ability to also process or generate other types of data, such as images or audio. These LLMs are also called large multimodal'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='LLMs are also called large multimodal models (LMMs).[20]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='As of 2024, the largest and most capable models are all based on the transformer architecture. Some recent implementations are based on other architectures, such as recurrent neural network variants'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='as recurrent neural network variants and Mamba (a state space model).[21][22][23]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='As machine learning algorithms process numbers rather than text, the text must be converted to numbers. In the first step, a vocabulary is decided upon, then integer indices are arbitrarily but'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='integer indices are arbitrarily but uniquely assigned to each vocabulary entry, and finally, an embedding is associated to the integer index. Algorithms include byte-pair encoding (BPE) and'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='include byte-pair encoding (BPE) and WordPiece. There are also special tokens serving as control characters, such as [MASK] for masked-out token (as used in BERT), and [UNK] ("unknown") for'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='in BERT), and [UNK] ("unknown") for characters not appearing in the vocabulary. Also, some special symbols are used to denote special text formatting. For example, "Ġ" denotes a preceding whitespace'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='"Ġ" denotes a preceding whitespace in RoBERTa and GPT. "##" denotes continuation of a preceding word in BERT.[24]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='For example, the BPE tokenizer used by GPT-3 (Legacy) would split tokenizer: texts -> series of numerical "tokens" as'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Tokenization also compresses the datasets. Because LLMs generally require input to be an array that is not jagged, the shorter texts must be "padded" until they match the length of the longest one.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='match the length of the longest one. How many tokens are, on average, needed per word depends on the language of the dataset.[25][26]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='As an example, consider a tokenizer based on byte-pair encoding. In the first step, all unique characters (including blanks and punctuation marks) are treated as an initial set of n-grams (i.e.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='as an initial set of n-grams (i.e. initial set of uni-grams). Successively the most frequent pair of adjacent characters is merged into a bi-gram and all instances of the pair are replaced by it. All'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='of the pair are replaced by it. All occurrences of adjacent pairs of (previously merged) n-grams that most frequently occur together are then again merged into even lengthier n-gram, until a'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='into even lengthier n-gram, until a vocabulary of prescribed size is obtained (in case of GPT-3, the size is 50257).[27] After a tokenizer is trained, any text can be tokenized by it, as long as it'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='can be tokenized by it, as long as it does not contain characters not appearing in the initial-set of uni-grams.[28]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='A token vocabulary based on the frequencies extracted from mainly English corpora uses as few tokens as possible for an average English word. An average word in another language encoded by such an'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='in another language encoded by such an English-optimized tokenizer is however split into suboptimal amount of tokens. GPT-2 tokenizer can use up to 15 times more tokens per word for some languages,'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='tokens per word for some languages, for example for the Shan language from Myanmar. Even more widespread languages such as Portuguese and German have "a premium of 50%" compared to English.[29]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Greedy tokenization also causes subtle problems with text completion.[30]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='In the context of training LLMs, datasets are typically cleaned by removing low-quality, duplicated, or toxic data.[31] Cleaned datasets can increase training efficiency and lead to improved'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='efficiency and lead to improved downstream performance.[32][33] A trained LLM can be used to clean datasets for training a further LLM.[34]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='With the increasing proportion of LLM-generated content on the web, data cleaning in the future may include filtering out such content. LLM-generated content can pose a problem if the content is'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='can pose a problem if the content is similar to human text (making filtering difficult) but of lower quality (degrading performance of models trained on it).[35]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Training of largest language models might need more linguistic data than naturally available, or that the naturally occurring data is of insufficient quality. In these cases, synthetic data might be'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="In these cases, synthetic data might be used. Microsoft's Phi series of LLMs is trained on textbook-like data generated by another LLM.[36]"),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Reinforcement learning from human feedback (RLHF) through algorithms, such as proximal policy optimization, is used to further fine-tune a model based on a dataset of human preferences.[37]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Using "self-instruct" approaches, LLMs have been able to bootstrap correct responses, replacing any naive responses, starting from human-generated corrections of a few cases. For example, in the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='of a few cases. For example, in the instruction "Write an essay about the main themes represented in Hamlet," an initial naive completion might be "If you submit the essay after March 17, your grade'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='the essay after March 17, your grade will be reduced by 10% for each day of delay," based on the frequency of this textual sequence in the corpus.[38]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='The largest LLM may be too expensive to train and use directly. For such models, mixture of experts (MoE) can be applied, a line of research pursued by Google researchers since 2017 to train models'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='researchers since 2017 to train models reaching up to 1 trillion parameters.[39][40][41]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Most results previously achievable only by (costly) fine-tuning, can be achieved through prompt engineering, although limited to the scope of a single conversation (more precisely, limited to the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='(more precisely, limited to the scope of a context window).[42]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='In order to find out which tokens are relevant to each other within the scope of the context window, the attention mechanism calculates "soft" weights for each token, more precisely for its'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='for each token, more precisely for its embedding, by using multiple attention heads, each with its own "relevance" for calculating its own soft weights. For example, the small (i.e. 117M parameter'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='example, the small (i.e. 117M parameter sized) GPT-2 model has had twelve attention heads and a context window of only 1k tokens.[44] In its medium version it has 345M parameters and contains 24'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='it has 345M parameters and contains 24 layers, each with 12 attention heads. For the training with gradient descent a batch size of 512 was utilized.[28]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='The largest models, such as Google\'s Gemini 1.5, presented in February 2024, can have a context window sized up to 1 million (context window of 10 million was also "successfully tested").[45] Other'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='also "successfully tested").[45] Other models with large context windows includes Anthropic\'s Claude 2.1, with a context window of up to 200k tokens.[46] Note that this maximum refers to the number'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='that this maximum refers to the number of input tokens and that the maximum number of output tokens differs from the input and is often smaller. For example, the GPT-4 Turbo model has a maximum'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='the GPT-4 Turbo model has a maximum output of 4096 tokens.[47]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Length of a conversation that the model can take into account when generating its next answer is limited by the size of a context window, as well. If the length of a conversation, for example with'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='of a conversation, for example with ChatGPT, is longer than its context window, only the parts inside the context window are taken into account when generating the next answer, or the model needs to'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='the next answer, or the model needs to apply some algorithm to summarize the too distant parts of conversation.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='The shortcomings of making a context window larger include higher computational cost and possibly diluting the focus on local context, while making it smaller can cause a model to miss an important'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='can cause a model to miss an important long-range dependency. Balancing them are a matter of experimentation and domain-specific considerations.'),
# ...
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='among diverse models. To convert BPT into BPW, one can multiply it by the average number of tokens per word.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="In the evaluation and comparison of language models, cross-entropy is generally the preferred metric over entropy. The underlying principle is that a lower BPW is indicative of a model's enhanced"),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="BPW is indicative of a model's enhanced capability for compression. This, in turn, reflects the model's proficiency in making accurate predictions."),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='A large number of testing datasets and benchmarks have also been developed to evaluate the capabilities of language models on more specific downstream tasks. Tests may be designed to evaluate a'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Tests may be designed to evaluate a variety of capabilities, including general knowledge, commonsense reasoning, and mathematical problem-solving.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='One broad category of evaluation dataset is question answering datasets, consisting of pairs of questions and correct answers, for example, ("Have the San Jose Sharks won the Stanley Cup?",'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='San Jose Sharks won the Stanley Cup?", "No").[122] A question answering task is considered "open book" if the model\'s prompt includes text from which the expected answer can be derived (for example,'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='answer can be derived (for example, the previous question could be adjoined with some text which includes the sentence "The Sharks have advanced to the Stanley Cup finals once, losing to the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Stanley Cup finals once, losing to the Pittsburgh Penguins in 2016."[122]). Otherwise, the task is considered "closed book", and the model must draw on knowledge retained during training.[123] Some'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='retained during training.[123] Some examples of commonly used question answering datasets include TruthfulQA, Web Questions, TriviaQA, and SQuAD.[123]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Evaluation datasets may also take the form of text completion, having the model select the most likely word or sentence to complete a prompt, for example: "Alice was friends with Bob. Alice went to'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='was friends with Bob. Alice went to visit her friend, ____".[1]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Some composite benchmarks have also been developed which combine a diversity of different evaluation datasets and tasks. Examples include GLUE, SuperGLUE, MMLU, BIG-bench, and HELM.[121][123] OpenAI'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='BIG-bench, and HELM.[121][123] OpenAI has released tools for running composite benchmarks, but noted that the eval results are sensitive to the prompting method.[124][125] Some public datasets'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='method.[124][125] Some public datasets contain questions that are mislabeled, ambiguous, unanswerable, or otherwise of low-quality, which can be cleaned to give more reliable benchmark scores.[126]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='It was previously standard to report results on a heldout portion of an evaluation dataset after doing supervised fine-tuning on the remainder. It is now more common to evaluate a pre-trained model'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='common to evaluate a pre-trained model directly through prompting techniques, though researchers vary in the details of how they formulate prompts for particular tasks, particularly with respect to'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='tasks, particularly with respect to how many examples of solved tasks are adjoined to the prompt (i.e. the value of n in n-shot prompting).'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Because of the rapid pace of improvement of large language models, evaluation benchmarks have suffered from short lifespans, with state of the art models quickly "saturating" existing benchmarks,'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='"saturating" existing benchmarks, exceeding the performance of human annotators, leading to efforts to replace or augment the benchmark with more challenging tasks.[127] In addition, there are cases'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='In addition, there are cases of "shortcut learning" wherein AIs sometimes "cheat" on multiple-choice tests by using statistical correlations in superficial test question wording in order to guess the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='question wording in order to guess the correct responses, without necessarily understanding the actual question being asked.[108]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Some datasets have been constructed adversarially, focusing on particular problems on which extant language models seem to have unusually poor performance compared to humans. One example is the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='compared to humans. One example is the TruthfulQA dataset, a question answering dataset consisting of 817 questions which language models are susceptible to answering incorrectly by mimicking'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='to answering incorrectly by mimicking falsehoods to which they were repeatedly exposed during training. For example, an LLM may answer "No" to the question "Can you teach an old dog new tricks?"'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='"Can you teach an old dog new tricks?" because of its exposure to the English idiom you can\'t teach an old dog new tricks, even though this is not literally true.[128]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Another example of an adversarial evaluation dataset is Swag and its successor, HellaSwag, collections of problems in which one of multiple options must be selected to complete a text passage. The'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='to complete a text passage. The incorrect completions were generated by sampling from a language model and filtering with a set of classifiers. The resulting problems are trivial for humans but at'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='problems are trivial for humans but at the time the datasets were created state of the art language models had poor accuracy on them. For example:'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='We see a fitness center sign. We then see a man talking to the camera and sitting and laying on a exercise ball. The man...'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='a) demonstrates how to increase efficient exercise work by running up and down balls.\nb) moves all his arms and legs and builds up a lot of muscle.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='c) then plays the ball and we see a graphics and hedge trimming demonstration.\nd) performs sit ups while on the ball and talking.[129]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='BERT selects b) as the most likely completion, though the correct answer is d).[129]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='In 2023, Nature Biomedical Engineering wrote that "it is no longer possible to accurately distinguish" human-written text from text created by large language models, and that "It is all but certain'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='models, and that "It is all but certain that general-purpose large language models will rapidly proliferate... It is a rather safe bet that they will change many industries over time."[130] Goldman'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='industries over time."[130] Goldman Sachs suggested in 2023 that generative language AI could increase global GDP by 7% in the next ten years, and could expose to automation 300 million jobs'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='expose to automation 300 million jobs globally.[131][132]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Memorization is an emergent behavior in LLMs in which long strings of text are occasionally output verbatim from training data, contrary to typical behavior of traditional artificial neural nets.'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='of traditional artificial neural nets. Evaluations of controlled LLM output measure the amount memorized from training data (focused on GPT-2-series models) as variously over 1% for exact'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='models) as variously over 1% for exact duplicates[133] or up to about 7%.[134]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='A 2023 study showed that when ChatGPT 3.5 turbo was prompted to repeat the same word indefinitely, after a few hundreds of repetitions, it would start outputting excerpts from its training data.[135]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Some commenters expressed concern over accidental or deliberate creation of misinformation, or other forms of misuse.[136] For example, the availability of large language models could reduce the'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='large language models could reduce the skill-level required to commit bioterrorism; biosecurity researcher Kevin Esvelt has suggested that LLM creators should exclude from their training data papers'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='exclude from their training data papers on creating or enhancing pathogens.[137]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='The potential presence of "sleeper agents" within LLM models is another emerging security concern. These are hidden functionalities built into the model that remain dormant until triggered by a'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='remain dormant until triggered by a specific event or condition. Upon activation, the LLM deviates from its expected behavior to make insecure actions.[138]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='LLM applications accessible to the public, like ChatGPT or Claude, typically incorporate safety measures designed to filter out harmful content. However, implementing these controls effectively has'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='these controls effectively has proven challenging. For instance, a 2023 study[139] proposed a method for circumventing LLM safety systems. Similarly, Yongge Wang[140] illustrated in 2024 how a'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="Wang[140] illustrated in 2024 how a potential criminal could potentially bypass ChatGPT 4o's safety controls to obtain information on establishing a drug trafficking operation."),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='While LLMs have shown remarkable capabilities in generating human-like text, they are susceptible to inheriting and amplifying biases present in their training data. This can manifest in skewed'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='data. This can manifest in skewed representations or unfair treatment of different demographics, such as those based on race, gender, language, and cultural groups.[141] Since English data is'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content="groups.[141] Since English data is overrepresented in current large language models' training data, it may also downplay non-English views.[142]"),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='AI models can reinforce a wide range of stereotypes, including those based on gender, ethnicity, age, nationality, religion, or occupation. This can lead to outputs that unfairly generalize or'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='to outputs that unfairly generalize or caricature groups of people, sometimes in harmful or derogatory ways.[143]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Notably, gender bias refers to the tendency of these models to produce outputs that are unfairly prejudiced towards one gender over another. This bias typically arises from the data on which these'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='arises from the data on which these models are trained. Large language models often assign roles and characteristics based on traditional gender norms.[141] For example, it might associate nurses or'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='example, it might associate nurses or secretaries predominantly with women and engineers or CEOs with men.[144]'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='Political bias refers to the tendency of algorithms to systematically favor certain political viewpoints, ideologies, or outcomes over others. Language models may also exhibit political biases. Since'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='also exhibit political biases. Since the training data includes a wide range of political opinions and coverage, the models might generate responses that lean towards particular political ideologies'),
#  Document(metadata={'source': '../Knowledgebase/Large_language_model.txt'}, page_content='towards particular political ideologies or viewpoints, depending on the prevalence of those views in the data.[145]')]

# %%
# Generate a list of unique UUIDs for each document in `docs`
uuids = [str(uuid4()) for _ in range(len(docs))]

# Add the documents to the vector store with the generated UUIDs
vector_store.add_documents(documents=docs, ids=uuids)
# Out:
# ['f1075d85-1d65-483b-9607-d927adf2b1d9',
#  '40fcaa31-a4ab-40f8-b538-15b14be84c56',
#  'b48acb20-287b-4f90-b17e-099b665d9dde',
#  'cc1a0277-cf8d-4117-859f-acf9eb774a19',
#  '9ac975d2-2b7f-4a38-a35d-7ab85f78594b',
#  '645fd3b8-f6bb-4fc9-b6a9-d4f7e177a09c',
#  '621f52a5-0087-4b76-8740-14c10cfed4a4',
#  '9ed3a22b-80f9-4912-a464-1cc059bd3cfd',
#  'ba444064-6777-473d-a23a-c54751aec3e7',
#  '298e887c-dfd3-4d99-9358-074965833a2d',
#  '6ff45836-59e1-43b7-a759-6364132c3798',
#  '0e7c2f2d-f41e-40a0-a661-78f9e2e66585',
#  '97f6217e-13b1-4567-8e63-d93e420014d9',
#  'cac82ce5-5a4c-44d9-882b-075f21c196a9',
#  '0d9878d0-31e5-4d83-b1fe-cf8312b78591',
#  '49756df8-3bac-483f-8792-bccba5b7853c',
#  '283eb911-5b10-499e-9ff9-e935489f732c',
#  'd0ceb5b1-e798-46b8-baff-b69bd111cfca',
#  '6a59aa5c-d5ec-408d-abe6-b553db0f059a',
#  '955b7f2f-6857-4d51-a936-5b86dae28790',
#  'a21def31-c336-4775-b3cf-74aeed4189dd',
#  '092c4ad4-a07a-4d67-8f12-16452abfab55',
#  'ecd6fa67-4d49-4a94-b987-4c2f557d9686',
#  '33d3578f-bc52-4bc6-be72-282102b5fdc4',
#  '6ba4d81c-2963-4a89-86b2-8790f97d98ba',
#  '1fdef8fd-01c2-4572-9a6e-9e4c58d85c39',
#  'ed5190da-de2a-48d3-a5ff-5425f107fc18',
#  'c2215495-c32d-4516-b19b-2789f829dc4e',
#  '2ddcb1ef-1a62-46d1-b4ca-6a495a457497',
#  'afd82111-1bfc-49fe-858d-5ae8eb24a58a',
#  'cd929954-eb74-4092-a4f7-f6adb34ff3b6',
#  '9229abe7-1e5c-4040-9a2f-0b50e1f5789a',
#  '91a0e52c-88b6-47ac-8171-80029b3b2bc0',
#  'e18368ac-9b0c-418f-b34d-de39bcf2802c',
#  '56d186f9-6207-43b3-bc63-cfb89834f88e',
#  '83aece83-3897-44c0-82bc-41995f85407a',
#  '8de36593-02c6-4834-bf2a-190ce4ce2296',
#  '7bec76d7-60fb-4eba-8dd1-a21428e91088',
#  '29effc92-5ae6-4dda-9658-6c96463ef9ca',
#  'ee32a3b6-42df-4807-b9be-b0567a2878a5',
#  'edbf15fe-ad3c-4297-abf0-8295ea90ae1e',
#  '561dd719-a11d-42ce-93bb-23f9404992b4',
#  '3f7bcfbc-b9c2-41a8-a33e-1d50f9802bb2',
#  'c71a0fca-364c-41ca-bc5f-152b8e355bde',
#  '2a78cffb-5ae6-4667-92ba-0a53770bd3c7',
#  'c1fe642c-c047-4ddc-a009-959241fef365',
#  '4f61a4d1-25ee-41cb-9e73-2b365681d067',
#  '6c12a881-4e1b-4836-9e7c-9ca5d6a80825',
#  '36815e72-450c-4be9-98b8-e4554f80b2dc',
#  '2e220d81-ee0f-43ab-8664-d6bcac0e0707',
#  '19c8f6b5-f356-4592-9a2f-3ed8dc1cb036',
#  'cd7385b1-89d2-49b5-b96c-1d8e4232de72',
#  '1efcb9c2-a2d6-4ecf-9a66-0de458ed533a',
#  '5fecd9b8-0853-4c6c-af67-16f4fb31de28',
#  '1ce7db86-9e8d-4cac-a76a-c2b32ad5010a',
#  '7b5f4caa-bd82-444c-8f86-2ba8aff9c02a',
#  'fc5503a7-8a93-4ab1-b5a2-16b543b79373',
#  'fb0fe652-d00d-4e6c-bfd0-39f8f80fdfc9',
#  'd23483ee-bc3c-4c19-8a12-f73436d36785',
#  'fe4f3748-23ef-4e71-b0f6-f7c1fdba995d',
#  'ebeae0d1-0ca7-47a9-a3b2-26979e2ec594',
#  'ea966e02-7522-4b94-afba-41f4931edf5c',
#  'f4a7d3dd-ced1-4355-9e1a-4658ac692eb9',
#  '2a7f2a3b-e209-4c35-b637-dbf5d35e3167',
#  '2d940a40-3c3e-459a-bd19-6ba339f3b2d7',
#  '161d2de9-ee73-4eb3-8592-377a68102232',
#  '07a7026f-7fc8-44ec-b787-688925498cc9',
#  'fd1fcef1-794c-4404-a9c9-b43fc0cc44e7',
#  '760d41e7-3d17-4793-ade4-867eb08db092',
#  '580cfd30-4155-40f3-a522-43273d48a524',
#  'c385c824-2d1a-446b-b0f7-0bf60cf9faa1',
#  '40d0c6b9-f0a2-46ec-8d59-a4e07ef0a99b',
#  'd406d736-fd67-4d2d-9f85-884fc2c3b31b',
#  'be66f20f-b60a-491f-9bf3-d9ae04e7f078',
#  '31a630cb-b698-4958-9f7c-269ebd8168cb',
#  'af7e4439-ac96-4c28-abad-5fb4cce9b2f1',
#  'ca59ef6b-f771-495b-8779-188f24c9038a',
#  '9d3ac00e-4efa-499d-a5eb-6317a700aac7',
#  '96c6dfd0-d8ad-42af-b99e-79e8fe6ea5c1',
#  'b4260fba-d23d-4754-b73b-bd14068de7fb',
#  '495084e1-e09b-4806-8383-82317fefbb03',
#  'b9136b90-6668-4afd-b216-b0ae1833183d',
#  '36c4e141-e7c0-462b-8a83-23bcc5fd0e07',
#  '35351e0b-4f0f-46b4-9fee-bcba9e899776',
#  '435927c8-8730-4eda-a2d5-05c5d0728cfc',
#  '1ade9dbe-a871-44b5-850e-9cc88f943e26',
#  '3eb24d92-9eaf-4b02-990a-2b77c506b861',
#  'e138d238-17ed-4b49-9134-1e6848043d76',
#  '196aa103-7b37-438c-a776-07f1c019c87f',
#  '20b418c7-273c-4495-b0ff-af34b09ff12c',
#  'b3ec9c45-11d8-42f9-8092-2b8f1729d78f',
#  'eaae4226-627c-4f5a-be1c-7a660368d7e4',
#  '507defe6-36ab-412c-a95c-841e6c52bde3',
#  'f306ac77-7b5a-43c7-a9c5-4323f0d2d42a',
#  '80bfd6f9-1a8e-473b-85b1-8ea2f01bc360',
#  'a5428bd9-4763-470d-a014-b71789bfe6e7',
#  'ba15ff2b-78e8-4aa2-bb35-4e3c0e11082c',
#  '679e117d-9c3c-42f2-8183-7a961b9403a6',
#  '65a42340-9773-41f8-83d0-51ce6e3a3f0f',
#  '8bc54bd7-ad48-4851-b2db-919003ed43cb',
#  '3244a0d3-e7cd-4012-9454-06dd6f5fd85f',
#  '6aa5ac22-e6db-410d-8215-9dbc64526ec9',
#  '04afcc90-67b3-4156-8586-c69502ddab41',
#  'e4f2ad81-6445-4afd-9608-6589ec6da912',
#  '569c2d1a-719f-489c-b099-fbe3719251a1',
#  'fb436d8a-d84a-4a02-855d-fee1de82a235',
#  '548ab6d0-eaf1-426e-aeb2-ef8bf3d28fea',
#  '83651d11-4480-4908-8abc-76f917aeb726',
#  '9c230e0c-9467-47d4-b979-9011108bcdda',
#  '507e1f0f-06da-49f7-a05c-9e46b49f13a5',
#  '35055d3b-7cc9-4a60-9ecc-f0bff863d982',
#  '748f5f42-a370-44a1-8723-09710b01ebbc',
#  '4360a47b-23de-45f3-8a22-095007231f2e',
#  '7d07f712-1d2f-491d-9e9a-ed3a47a91284',
#  '5d5c9fd1-8452-4d41-9973-30553ef776df',
#  '4ec1ce71-0773-4863-9ede-78fa48b34b05',
#  'f26d11fd-04d4-4ba7-bb25-0b12e24b18e0',
#  'd14d9cec-6509-4c5d-bfb4-c79ccd4acf2a',
#  'dd3a089b-2397-4188-8f65-c83163b78005',
#  '769f3476-9933-4866-b246-54619935d0a9',
#  '9b9f6406-9c20-4738-a88b-6ccce027d095',
#  '2f9e7326-63da-4457-8155-7cbb5423cb83',
#  'b0699cd3-86df-417f-8139-ded704531515',
#  '4b841b6f-4b24-456f-8cfb-15a0b8d9b715',
#  '1409f8f8-eae6-43a9-99ec-c6802939f4e2',
#  '93cc85ad-a3e7-4495-97bc-af6dc297d839',
#  'cf5252ff-686a-452e-bbd9-618b4af195ba',
#  '6fdef14a-7b4d-4371-aab8-cffb48dac5f2',
#  '7aec94f0-3a81-426e-ae04-6e10933cc7d7',
#  'c7d893cd-371a-41e6-b47a-a344d72ca6f4',
#  'cf474971-dc3e-40d6-810c-1e736595cfc3',
#  '66fc7091-cfb6-4761-b207-0ddbe1f37c4b',
#  '8f08f641-e8ed-439d-9c14-1e9f4a52e3fb',
#  'f18f12ce-f743-4551-ae5e-ce057acff32d',
#  'bbf5187f-5f73-4013-b067-ae229759e73b',
#  '327309a2-cf85-4894-947c-fafe5bc8f1f0',
#  '8c933d62-ee52-481e-9a09-90bde31946e3',
#  '90be7de4-0619-4f27-9330-8cb1ed8f6a63',
#  'a5bda7e3-0cb8-4011-8e0c-ff42b2a6538f',
#  '6c8d28af-d27c-4c89-afcf-0a1ea85bec22',
#  '48d51be1-08f9-46e6-b800-5b543fae34d8',
#  '4e0b5408-f3d9-41ed-9af7-9257c77590a1',
#  '08f1efd2-9575-4de0-b54f-f8b4cf1672f9',
#  'ee4d3704-590e-4544-87fc-061827a8924d',
#  'fef4cc71-5f77-4254-9f36-14a34fc78134',
#  '1ec85089-d4c8-42fc-83a1-5fb3c68371b6',
#  'f6efffaf-cf67-4ac0-8a59-6ad7bcf93574',
#  '94caf36e-bb91-4c49-a99f-5a970d0540a2',
#  'a2d78a8e-0353-4c14-912f-f2959b4f18ca',
#  '9010166f-ec5c-4c57-81ce-4bf424404cd1',
#  '012932f3-a173-45de-bc13-4791d692fa2b',
#  '5d2f2d78-23a9-4678-93e7-f05b854a6ebc',
#  '79ccaa7a-c900-45a5-ac48-497cfd7746cb',
#  'bfb9efb0-f970-49fa-913d-5aa628a75ad1',
#  '4548e1d4-7d5c-45cd-ac49-1d12bb32525e',
#  'e9042922-b757-463b-bae6-581b9e5572b8',
#  'fdb73331-703a-4b16-b2e3-ab5ac47cde37',
#  'c7d4eb23-1ef3-41a3-9810-68928bbdb99f',
#  'be07f511-02cf-4f37-8550-ce6b69de07de',
#  '955ef72e-3fb9-4f74-ac3e-5fbb5cdc2ee6',
#  '6edf568d-d99a-473b-b02b-d0a42e96377a',
#  'bee25532-c7d7-4cca-9795-18ce3f9da1d8',
#  '66c128e7-e736-4e0f-a281-66cc42f465b4',
#  'daf0ba95-8a2f-4206-9eb6-7b76b309254c',
#  '40fe7c95-ee38-4563-be03-026e0571d132',
#  '178c8377-b864-4eb0-b196-514b7e81c06b',
#  '330dec3f-ca56-46ce-bdfa-abf327415611',
#  '65171391-bcfa-49a2-981c-1530d353bb0f',
#  '64fabc1a-b951-420c-be84-252caafd6f22',
#  'dff41cc8-5423-4ae1-8c7b-192b46f638be',
#  '2a958623-2108-4759-b363-5904ef4071f2',
#  '9ccc0a06-821e-426b-92a8-a5c5d2d2cd58',
#  'cd17c39e-fd2b-4be1-95ce-a9e0c85bd55d',
#  'edc440ac-19d4-45cd-8694-dd91044ef0ad',
#  'd1477a67-2542-4961-86fc-209ba0399f52',
#  '3d22856f-72c0-4c45-91b3-2557323098f8',
#  'ea4740b5-40dd-42e9-a1bb-b491bea7e16f',
#  '10f46422-1124-4e19-a905-43d52e98b003',
#  '1ff48be8-cb7f-4332-bac7-f6cf4f36831c',
#  '5d84034b-3ee7-4d1c-a464-8405b2549495',
#  '5443ee3c-10bd-4455-b280-05f263ac719a',
#  '91841820-9be2-4bc0-a840-85d7791f95a5',
#  'de923fb0-f33f-44d1-a14f-18090185fd31',
#  '834658ec-cf71-4996-9c02-23d55862641c',
#  'cadeb3ec-c230-4b52-8e6d-7f50d5d096ee',
#  '927071e4-37d9-4c0c-998a-a3b2336536c6',
#  '6cfd83da-c910-4193-a405-72ab4d792cf3',
#  '1a7fe8bf-ba41-4cf3-8609-908c7abc365a',
#  '5587e423-aef5-43db-8ef0-6cfda218172e',
#  '15a30b22-4536-4da9-b006-27109e4516c9',
#  '18ac5f5c-f71b-4cd6-b146-cc78b66ca843',
#  '4a6376a7-0812-4ee9-acec-6730c3935dc9',
#  '0979eb27-4e24-4542-8aa1-34a3188afec0',
#  'e964503b-1136-4c5c-9fb8-82e71cd06b96',
#  'e8f45d28-5431-4574-9bc7-d8d2ba7c2383',
#  '5260ac55-14c8-439b-9a9b-8c3170b3049b',
#  'fa051906-5f27-4fbf-b471-602866725c47',
#  '97f436e6-9cd0-4884-a126-756c52352184',
#  '43f078d7-5572-42f2-8bd1-b623f78a7534',
#  '84749265-1231-4453-93a2-82e168873255',
#  '9e80e286-3230-4c24-84d6-4ef269391810',
#  '2636d882-a8c4-4617-be20-2a9e21e85283',
#  '6bd25bab-6e37-49a8-bf02-0809f241925f',
#  'b0cb2b52-8c40-4393-8947-c52abdf44d81',
#  '35d6acee-6488-4c02-915a-f047a1a27d3a',
#  'b0d45f78-80a5-4f58-81f7-a3731a87a53d',
#  '418a96a4-5f4c-4b3e-b98f-a8631d06a3d0',
#  '93dd2aa2-a9d8-4474-8099-9346aa733657',
#  'c14fdc20-dd2b-492b-8981-e33da6f99073',
#  '4cf30d02-f457-4767-84d4-4a938a57bc94',
#  'b5553530-3969-46e4-819b-305eafa0d755',
#  '2fd7b827-4b48-4e75-b714-b49345572527',
#  'f50c3e23-84d8-45c8-9ffb-33149bce75d3',
#  '4ccfef42-32e4-4362-93a1-618ea00b5b78',
#  '0d5e291a-4e19-40fa-81e9-71e5b488ae52',
#  'df0a99c9-46b4-4d8e-92c1-0a62aa724977',
#  '946eee6c-5ade-4039-8795-e4ac2e72d4d6',
#  'a83781b6-dcb4-4d35-95ea-816c50fe26b4',
#  '858fa5d4-699e-4143-8a83-e45991c60f6e',
#  'e6a40eb9-9219-4194-b356-18d8afd91043',
#  '5909f39a-6235-495c-b591-b3e0c652fe23',
#  '65e9017a-944b-4d9a-bcf8-318e095bb954',
#  '4aec953c-3daf-4d72-86b2-8a1fd71758f6',
#  '87159421-683e-4f3d-aa57-22721ef26966',
#  '15a23bbf-a2e9-4de0-be9a-7d4496eaec93',
#  'c8c4eecb-aa04-4f29-8d99-75ab2085c413',
#  '2ac8572a-1ae6-4c81-8e44-9e6b0477e18b',
#  '5123d7de-e377-4807-a8eb-d86c95807fc7',
#  '8e2bd815-6b59-4080-b2a9-42f523e55fa6',
#  '7ec44be7-e20f-4f92-9a1b-50371138c823',
#  'a3c76c34-9a61-473e-a094-27077fca1a28',
#  '377a8916-c0bc-4571-9184-d0c760337d04',
#  '73be34b3-7d47-4ff7-853e-0e40dc485d23',
#  '51babe73-9fd5-409c-9191-e25f89db3818',
#  '76cc6ca5-93c6-477b-a794-1779d18b9ad3',
#  '827dc669-d4b5-4a4b-a30a-8323aa7b4bd2',
#  'b49fd591-9dac-4838-a31d-88a014d2659a',
#  '15ac8528-f1bf-4262-ac77-763d0a56bfc9',
#  'e6058c53-e799-4b1a-a4db-143eef3a6b74',
#  '147c4871-9498-4b82-8ba0-bdc5160c9294',
#  'efe079e9-d028-412d-abe0-cc26b5608670',
#  'c870f724-37c3-4faa-9a3f-0e3abb002d42',
#  '4f4cc4e9-c0da-44fd-a353-ef17dfe6d85c',
#  '70b2e2b1-e365-4c72-acda-7376d13ec903',
#  'd30c462f-7cf4-4604-bcbe-73b2897774fa',
#  '69536fbf-fb4a-472a-9217-5d995524731f',
#  '96fc1bd5-fc1f-4bbf-a0b2-d94b4313652c',
#  '0655348a-02f8-4bfa-8fa5-43cd81d04ae6',
#  'ca400e25-2601-4699-9ad5-691f44f2010e',
#  'd58548b2-3ede-4f48-8daf-921a0c89f65f',
#  'af578f2a-6974-44fe-a503-350dd4a9de48',
#  '69219966-4274-4077-a79d-a6d2ee419170',
#  '65b10e4e-31fd-46f4-a6d2-ed00889f9436',
#  'eba9c046-b540-4e35-aa03-3e44cc963af8',
#  'a4ba9b8e-3eb6-4bfa-ae4f-5a5de15d60e9',
#  '90708eec-456a-4991-8c4a-ed3e404d0c2b',
#  '334616b4-7e9c-42df-8119-45eb66dd6351',
#  'b5d9f0db-5548-463a-866e-d41c41c35b88',
#  '3d25de4a-827c-455e-872f-d811d4d23f03',
#  '1f72563d-c02c-4095-8094-431865b09161',
#  '9517d031-9913-48a9-b3cc-471f5b5f6b33',
#  'cdf51399-fee5-48d1-82f9-141c3858f799',
#  '77f09ac2-ee0d-4cdc-98f8-cf58b7d591d9',
#  'b2dccd63-bc83-412c-86a0-3216353b43c7',
#  '9df18dac-e107-49a3-82c4-33e24d312223',
#  '56cddfab-c9b3-4018-be01-09f4d16829d7',
#  '0ec23f91-459a-4e50-8dd7-dbfaf6f448c0',
#  'bb1c2111-f958-43b9-ac0f-562c2d7ea230',
#  'c7349515-e315-4a12-8007-4a15e6ee0b51',
#  '59c2295b-c2fc-4267-992a-2ec2a3713429',
#  'caf2529a-8ad2-4304-aa5d-b7524517aec6',
#  '83756af8-a7aa-41b3-a4fd-b8dbfa8ae1c6',
#  '896f6998-6cb0-4b7a-8a49-325ed6ba3fe6',
#  '52f739ff-a306-4153-a0f1-209d8ac36f62',
#  'f3d66e82-6ded-4db9-aef3-1d86e155c52e',
#  '9c28f285-e2b8-46a2-bc1d-b212037fc435',
#  'a2c59492-a770-4225-8ac0-ebf4f26d2d85',
#  'd06fcc1e-7b20-4b3f-aa67-d4ca2dbf76cf',
#  '95dea09d-d93f-42d7-846e-fabb8b4e8694',
#  'e272017f-489a-4449-b46f-46115c0b27f6',
#  'f8ec8e14-4101-4b11-af98-b2bb165e6782',
#  'c5f1383a-1c15-4d3a-8ea8-5382dad11264',
#  'd8cc08a8-67bd-408a-b3d6-e28cda11e3cb',
#  'ac207ae0-7c60-4a72-802c-f8f668923029',
#  '201118ae-74f5-4762-99e0-67b2bf476cb5',
#  '00b91b48-4356-42ff-80c3-9b51cb39a47e',
#  'f550931c-812a-4555-bc4b-d7ec76fbad05',
#  '15fd3f17-6862-4104-8daa-d4188b9b0303',
#  '9f9897dd-f109-4c28-bd91-3230001f7167',
#  'ec1c429f-58ad-40d5-a444-ea7cec985128',
#  '1d830930-2ee5-44cb-a113-2519cb67f2d4',
#  '94cb0fb4-5188-4c6f-b921-54c47278a5d0',
#  'cbd1afc4-7e99-4f9d-b5dc-ab5936d20a66',
#  '8daa112b-b2d9-4b80-9d48-b1724f551560',
#  '7190c37e-fce3-4e83-adfa-ff675c1f6170',
#  'fa2fec32-1255-4ec0-add2-f9b09ae2a457',
#  '1fa1f752-beb0-4039-aab5-c7c0fbb46bad',
#  '757d553a-6d3e-45e9-bda1-b36652ae5930',
#  '8665177e-a6d8-4316-b3ee-c84d2160448b',
#  '8df30724-ca16-47da-8039-dd2f1092c06c',
#  '2dfe0af4-7f72-4b9e-be0e-45f65315b62a',
#  'c8572b8d-5e2f-4d3c-ad70-2d58de42d87e',
#  '8d13568f-bfc9-4c65-ae64-c3818b6b871b',
#  '8406dd5d-5608-4042-969c-832e5ee913a9',
#  '5376170c-3bb2-4cfc-b70d-793a8edbf743',
#  'd887880e-f417-48e9-afb3-f748854a860e',
#  'aa59cde2-dc44-44a5-87d5-15d371ff05e4',
#  '0698dc20-21f9-462c-af4d-aafd37d028a9',
#  '70c0f4a3-4db2-4455-a52e-d6e85fca484c',
#  'b0913607-f368-42ff-9ced-9283abc7d1ca',
#  '9e425c12-686c-4c07-b592-224caae21434',
#  '45c9f876-7176-45d4-8261-67cfe091b084',
#  'fc036645-d913-49f9-ad70-cceb3e0f78d9',
#  'fe0daf3e-96d9-4c8a-935a-f58f5309be8a',
#  'f0e50347-38bf-451a-9be4-d07a4971bed9',
#  '2db697b4-d346-497d-a208-bc038c5df650',
#  'a146c509-1f29-46e9-b1b1-f170697da2ae',
#  '4a53b324-36be-42d5-ab73-72209c2a67f6',
#  'fa9ac1b6-027a-4743-a928-896622e4974d',
#  '91b6b8db-b724-4127-830c-3f091bcfad49',
#  '3c3824fa-ea4f-4c6b-8837-aad2d526d730',
#  '328465d3-de8f-4e3e-a5fd-9992c3b53f91',
#  '0a677005-f48e-4c38-a132-91285ad7bd32',
#  '30cd1229-26ce-44c6-a276-d56d8084b1de',
#  '2bb1e6ac-8e68-4399-8a70-d72df4e12f3d',
#  'af7a491a-611c-4143-997b-397c4865b831',
#  '832aacfa-ac60-42a0-94f2-2a5c6efd2a31',
#  '9b042b50-c940-43b5-b7df-38e01df189b2',
#  '93b874b3-3704-498d-8818-956b61e9daf3',
#  '3d19010e-b38d-4bf7-bb24-e08c3ed4ba4d',
#  '2e96dbf2-f073-4e8f-8417-04a057d939d7',
#  'f83a2415-3070-4f90-b3bb-dd819ecdfae8',
#  '3e406708-6966-4325-a0ab-ffa50a1f73e5',
#  'b6876adf-d2f4-4b7d-af45-bef5ec1ee0d0',
#  'be8b75b4-a705-48f5-9f58-08e783a34e73',
#  '37b9d929-88e5-4ae8-bb33-36eb621ce0d9',
#  'e3e163e4-b99b-4e7a-82dd-4e5a409b535d',
#  'a69cb045-1df0-4b31-aacc-a722faa4d360',
#  'b8ff77d6-624a-4ee6-88a9-025610a66fc1',
#  'd640a1e6-0a32-4754-9520-0096ff966140',
#  '8ceee5da-1b2b-4c7a-9a4a-ebf86b50c43a',
#  '3926a188-455f-4b68-aabd-b8ce1d65614d',
#  'aa0f59b2-1c2f-474c-9e53-1ea3153a763c',
#  '1b0c98da-1283-4323-b2da-16c50fbb6ada',
#  '43153e5c-67a4-41d8-b8c1-f8d287f12fd9',
#  '1224ebf1-0ca4-4c66-97c2-44bddb33e1fe',
#  '4bf3eaf0-db69-47fd-b788-c321f2926f53',
#  '2d5f4f1d-d6e5-4d07-ba0d-4c2b5560c371',
#  'cb3f9a2a-e3ae-4692-b5b4-5cc24b0b09a2',
#  'ebaaeb54-e532-480a-9df4-8d2b231f098e',
#  'e6076da9-7a0e-4e49-ae54-2cbd4375252b',
#  'f5cc1a7e-1102-4bd8-86bd-56a266b1c71e',
#  '4a1c707d-84fe-422a-9117-5997a741169c',
#  '99dea29b-4334-422c-bf3e-bc407a2b6d97',
#  '59bc8e2e-9af6-4a20-994a-3e37e15be1a5',
#  '473a5864-d787-4de0-bd27-d7023aa0065e',
#  '7210ad57-429f-4e70-8080-11e35a09292d',
#  '8ed49839-c3b4-44ea-8d17-a01dd1cc03ef',
#  '82ab4d6f-4029-445c-8a4c-a407c02c4cc5',
#  'bf14e4f9-f6da-4e04-a7a5-1d5965502495',
#  'e99886fb-3f29-4c94-99d8-19f233e5b6f9',
#  '20e298c1-e5d7-4c20-b0ff-f1eed5b3217b',
#  'bb141a16-ef67-4b8c-a3be-ed9df20d0c9f',
#  '5899abaa-e8c5-4f0c-8d6d-aa736db34770',
#  'f8351322-3ad8-4fda-bc6a-4da14efa066a',
#  '021e20b1-3a57-40d5-8e41-87622975cb8b',
#  'd9ca6029-0f1f-44ed-b28b-eb8c21b8a127',
#  '2f6e575b-6da9-422e-ae35-a6a8219f53db',
#  'd17f8616-afa7-44a9-8263-00ebe37bcc70',
#  'd7d8f80b-f80a-41e8-9ab3-29d9e41d1e4e',
#  'ad62e86b-74bd-4b26-b0dc-857c724087c4']

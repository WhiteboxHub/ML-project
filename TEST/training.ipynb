# %%
# %pip install mlflow
# Out:
# ...
#      ---------------------------------------- 27.4/27.4 MB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 114.9/114.9 KB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 147.8/147.8 KB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 233.6/233.6 KB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.9/5.9 MB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 103.0/103.0 KB 2.0 MB/s eta 0:00:00
# ...
#   Using cached pyarrow-18.1.0-cp310-cp310-win_amd64.whl (25.1 MB)
# ...
#      -------------------------------------- 106.3/106.3 KB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.2/56.2 KB 3.1 MB/s eta 0:00:00
# ...
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# ...
#      -------------------------------------- 637.5/637.5 KB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 434.5/434.5 KB 1.9 MB/s eta 0:00:00
# ...

# %%
# %pip install torch torchvision scikit-learn
# Out:
# ...
#   Using cached torchvision-0.20.1-cp310-cp310-win_amd64.whl (1.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\ajukh\OneDrive\Desktop\1\ML-project\myenv\Scripts\python.exe -m pip install --upgrade pip' command.
